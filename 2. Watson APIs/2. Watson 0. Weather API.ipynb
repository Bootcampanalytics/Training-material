# %% [markdown]
# # Weather API
#
# https://console.ng.bluemix.net/docs/services/Weather/weather_rest_apis.html#rest_apis

# %%
# The code was removed by DSX for sharing.

# %%
import requests
import json
def print_api_resp(url,credentials):
    response = requests.get(credentials_1["url"]+":443/"+url)  
    parsed = json.loads(response.text)
    print json.dumps(parsed, indent=4, sort_keys=True)

# %% [markdown]
# ### You can use the following request to retrieve the 48-hour hourly forecast for the latitude and longitude coordinates for Ottawa, ON, Canada:

# %%
print_api_resp("api/weather/v1/geocode/45.42/75.69/forecast/hourly/48hour.json?units=m&language=en-US",credentials_1)
# Out:
# {
#     "forecasts": [
#         {
#             "class": "fod_short_range_hourly",
#             "clds": 87,
#             "day_ind": "D",
#             "dewpt": -2,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488969471,
#             "fcst_valid": 1488970800,
#             "fcst_valid_local": "2017-03-08T17:00:00+0600",
#             "feels_like": 0,
#             "golf_category": "Very Poor",
#             "golf_index": 2,
#             "gust": null,
#             "hi": 2,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1025.0,
#             "num": 1,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 0,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 75,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 2,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.35,
#             "uv_warning": 0,
#             "vis": 14.0,
#             "wc": 0,
#             "wdir": 315,
#             "wdir_cardinal": "NW",
#             "wspd": 7,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_short_range_hourly",
#             "clds": 87,
#             "day_ind": "D",
#             "dewpt": -2,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488969471,
#             "fcst_valid": 1488974400,
#             "fcst_valid_local": "2017-03-08T18:00:00+0600",
#             "feels_like": -1,
#             "golf_category": "Very Poor",
#             "golf_index": 2,
#             "gust": null,
#             "hi": 1,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1024.8,
#             "num": 2,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 2,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 77,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 1,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.07,
#             "uv_warning": 0,
#             "vis": 12.0,
#             "wc": -1,
#             "wdir": 339,
#             "wdir_cardinal": "NNW",
#             "wspd": 7,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_short_range_hourly",
#             "clds": 79,
#             "day_ind": "N",
#             "dewpt": -2,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488969471,
#             "fcst_valid": 1488978000,
#             "fcst_valid_local": "2017-03-08T19:00:00+0600",
#             "feels_like": -3,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": 0,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1024.7,
#             "num": 3,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 2,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 86,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 0,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 12.0,
#             "wc": -3,
#             "wdir": 87,
#             "wdir_cardinal": "E",
#             "wspd": 7,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_short_range_hourly",
#             "clds": 72,
#             "day_ind": "N",
#             "dewpt": -3,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488969471,
#             "fcst_valid": 1488981600,
#             "fcst_valid_local": "2017-03-08T20:00:00+0600",
#             "feels_like": -5,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -1,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1024.8,
#             "num": 4,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 3,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 92,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -1,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 11.0,
#             "wc": -5,
#             "wdir": 143,
#             "wdir_cardinal": "SE",
#             "wspd": 8,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_short_range_hourly",
#             "clds": 67,
#             "day_ind": "N",
#             "dewpt": -3,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488969471,
#             "fcst_valid": 1488985200,
#             "fcst_valid_local": "2017-03-08T21:00:00+0600",
#             "feels_like": -6,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -2,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1024.7,
#             "num": 5,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 3,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 93,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -2,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 9.0,
#             "wc": -6,
#             "wdir": 146,
#             "wdir_cardinal": "SE",
#             "wspd": 8,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_short_range_hourly",
#             "clds": 65,
#             "day_ind": "N",
#             "dewpt": -3,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488969471,
#             "fcst_valid": 1488988800,
#             "fcst_valid_local": "2017-03-08T22:00:00+0600",
#             "feels_like": -7,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -3,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1024.57,
#             "num": 6,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 6,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 99,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -3,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -7,
#             "wdir": 148,
#             "wdir_cardinal": "SSE",
#             "wspd": 9,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_short_range_hourly",
#             "clds": 65,
#             "day_ind": "N",
#             "dewpt": -4,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488969471,
#             "fcst_valid": 1488992400,
#             "fcst_valid_local": "2017-03-08T23:00:00+0600",
#             "feels_like": -8,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -4,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1024.2,
#             "num": 7,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 7,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -4,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -8,
#             "wdir": 152,
#             "wdir_cardinal": "SSE",
#             "wspd": 9,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 66,
#             "day_ind": "N",
#             "dewpt": -5,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1488996000,
#             "fcst_valid_local": "2017-03-09T00:00:00+0600",
#             "feels_like": -8,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -5,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1023.97,
#             "num": 8,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 8,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -5,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -8,
#             "wdir": 158,
#             "wdir_cardinal": "SSE",
#             "wspd": 8,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 67,
#             "day_ind": "N",
#             "dewpt": -5,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1488999600,
#             "fcst_valid_local": "2017-03-09T01:00:00+0600",
#             "feels_like": -9,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -5,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1023.5,
#             "num": 9,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 9,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -5,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -9,
#             "wdir": 159,
#             "wdir_cardinal": "SSE",
#             "wspd": 8,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 69,
#             "day_ind": "N",
#             "dewpt": -5,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489003200,
#             "fcst_valid_local": "2017-03-09T02:00:00+0600",
#             "feels_like": -8,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -5,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1022.9,
#             "num": 10,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 8,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -5,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -8,
#             "wdir": 158,
#             "wdir_cardinal": "SSE",
#             "wspd": 8,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 72,
#             "day_ind": "N",
#             "dewpt": -5,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489006800,
#             "fcst_valid_local": "2017-03-09T03:00:00+0600",
#             "feels_like": -8,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -5,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1022.4,
#             "num": 11,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 9,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -5,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -8,
#             "wdir": 157,
#             "wdir_cardinal": "SSE",
#             "wspd": 8,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 79,
#             "day_ind": "N",
#             "dewpt": -5,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489010400,
#             "fcst_valid_local": "2017-03-09T04:00:00+0600",
#             "feels_like": -9,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -5,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1022.06,
#             "num": 12,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 9,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -5,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -9,
#             "wdir": 151,
#             "wdir_cardinal": "SSE",
#             "wspd": 8,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 88,
#             "day_ind": "N",
#             "dewpt": -5,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489014000,
#             "fcst_valid_local": "2017-03-09T05:00:00+0600",
#             "feels_like": -10,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -5,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1021.8,
#             "num": 13,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 9,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": -5,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -10,
#             "wdir": 153,
#             "wdir_cardinal": "SSE",
#             "wspd": 10,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 93,
#             "day_ind": "N",
#             "dewpt": -5,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489017600,
#             "fcst_valid_local": "2017-03-09T06:00:00+0600",
#             "feels_like": -9,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -5,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1021.7,
#             "num": 14,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 8,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": -5,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -9,
#             "wdir": 146,
#             "wdir_cardinal": "SE",
#             "wspd": 10,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 94,
#             "day_ind": "N",
#             "dewpt": -5,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489021200,
#             "fcst_valid_local": "2017-03-09T07:00:00+0600",
#             "feels_like": -9,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -5,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1021.8,
#             "num": 15,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 8,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": -5,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -9,
#             "wdir": 148,
#             "wdir_cardinal": "SSE",
#             "wspd": 11,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 96,
#             "day_ind": "D",
#             "dewpt": -5,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489024800,
#             "fcst_valid_local": "2017-03-09T08:00:00+0600",
#             "feels_like": -10,
#             "golf_category": "Very Poor",
#             "golf_index": 0,
#             "gust": null,
#             "hi": -5,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1022.0,
#             "num": 16,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 8,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": -5,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.03,
#             "uv_warning": 0,
#             "vis": 9.0,
#             "wc": -10,
#             "wdir": 151,
#             "wdir_cardinal": "SSE",
#             "wspd": 12,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 96,
#             "day_ind": "D",
#             "dewpt": -4,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489028400,
#             "fcst_valid_local": "2017-03-09T09:00:00+0600",
#             "feels_like": -8,
#             "golf_category": "Very Poor",
#             "golf_index": 0,
#             "gust": null,
#             "hi": -4,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1022.0,
#             "num": 17,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 8,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": -4,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.17,
#             "uv_warning": 0,
#             "vis": 10.0,
#             "wc": -8,
#             "wdir": 156,
#             "wdir_cardinal": "SSE",
#             "wspd": 12,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 96,
#             "day_ind": "D",
#             "dewpt": -3,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489032000,
#             "fcst_valid_local": "2017-03-09T10:00:00+0600",
#             "feels_like": -7,
#             "golf_category": "Very Poor",
#             "golf_index": 1,
#             "gust": null,
#             "hi": -2,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1021.9,
#             "num": 18,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 7,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 96,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": -2,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.48,
#             "uv_warning": 0,
#             "vis": 12.0,
#             "wc": -7,
#             "wdir": 152,
#             "wdir_cardinal": "SSE",
#             "wspd": 12,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 96,
#             "day_ind": "D",
#             "dewpt": -2,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489035600,
#             "fcst_valid_local": "2017-03-09T11:00:00+0600",
#             "feels_like": -4,
#             "golf_category": "Very Poor",
#             "golf_index": 1,
#             "gust": null,
#             "hi": 0,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1021.7,
#             "num": 19,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 7,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 87,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 0,
#             "uv_desc": "Low",
#             "uv_index": 1,
#             "uv_index_raw": 0.87,
#             "uv_warning": 0,
#             "vis": 13.0,
#             "wc": -4,
#             "wdir": 155,
#             "wdir_cardinal": "SSE",
#             "wspd": 12,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 96,
#             "day_ind": "D",
#             "dewpt": -2,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489039200,
#             "fcst_valid_local": "2017-03-09T12:00:00+0600",
#             "feels_like": -2,
#             "golf_category": "Very Poor",
#             "golf_index": 2,
#             "gust": null,
#             "hi": 1,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1021.5,
#             "num": 20,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 16,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 79,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 1,
#             "uv_desc": "Low",
#             "uv_index": 1,
#             "uv_index_raw": 1.21,
#             "uv_warning": 0,
#             "vis": 12.0,
#             "wc": -2,
#             "wdir": 168,
#             "wdir_cardinal": "SSE",
#             "wspd": 12,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 95,
#             "day_ind": "D",
#             "dewpt": -2,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489042800,
#             "fcst_valid_local": "2017-03-09T13:00:00+0600",
#             "feels_like": 0,
#             "golf_category": "Poor",
#             "golf_index": 3,
#             "gust": null,
#             "hi": 3,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1021.2,
#             "num": 21,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 14,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 72,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 3,
#             "uv_desc": "Low",
#             "uv_index": 1,
#             "uv_index_raw": 1.36,
#             "uv_warning": 0,
#             "vis": 12.0,
#             "wc": 0,
#             "wdir": 188,
#             "wdir_cardinal": "S",
#             "wspd": 12,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 93,
#             "day_ind": "D",
#             "dewpt": -2,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489046400,
#             "fcst_valid_local": "2017-03-09T14:00:00+0600",
#             "feels_like": 0,
#             "golf_category": "Poor",
#             "golf_index": 3,
#             "gust": null,
#             "hi": 4,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1020.8,
#             "num": 22,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 12,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 68,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 4,
#             "uv_desc": "Low",
#             "uv_index": 1,
#             "uv_index_raw": 1.27,
#             "uv_warning": 0,
#             "vis": 12.0,
#             "wc": 0,
#             "wdir": 205,
#             "wdir_cardinal": "SSW",
#             "wspd": 14,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 91,
#             "day_ind": "D",
#             "dewpt": -2,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489050000,
#             "fcst_valid_local": "2017-03-09T15:00:00+0600",
#             "feels_like": 1,
#             "golf_category": "Fair",
#             "golf_index": 4,
#             "gust": null,
#             "hi": 4,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1020.5,
#             "num": 23,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 5,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 65,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 4,
#             "uv_desc": "Low",
#             "uv_index": 1,
#             "uv_index_raw": 0.98,
#             "uv_warning": 0,
#             "vis": 11.0,
#             "wc": 1,
#             "wdir": 215,
#             "wdir_cardinal": "SW",
#             "wspd": 14,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 89,
#             "day_ind": "D",
#             "dewpt": -2,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489053600,
#             "fcst_valid_local": "2017-03-09T16:00:00+0600",
#             "feels_like": 1,
#             "golf_category": "Fair",
#             "golf_index": 4,
#             "gust": null,
#             "hi": 5,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1020.4,
#             "num": 24,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 5,
#             "precip_type": "rain",
#             "qpf": 0.0,
#             "rh": 64,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 5,
#             "uv_desc": "Low",
#             "uv_index": 1,
#             "uv_index_raw": 0.59,
#             "uv_warning": 0,
#             "vis": 11.0,
#             "wc": 1,
#             "wdir": 227,
#             "wdir_cardinal": "SW",
#             "wspd": 15,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 85,
#             "day_ind": "D",
#             "dewpt": -1,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489057200,
#             "fcst_valid_local": "2017-03-09T17:00:00+0600",
#             "feels_like": 1,
#             "golf_category": "Fair",
#             "golf_index": 4,
#             "gust": null,
#             "hi": 4,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1020.5,
#             "num": 25,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 11,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 66,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 4,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.36,
#             "uv_warning": 0,
#             "vis": 11.0,
#             "wc": 1,
#             "wdir": 245,
#             "wdir_cardinal": "WSW",
#             "wspd": 14,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 79,
#             "day_ind": "D",
#             "dewpt": -1,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489060800,
#             "fcst_valid_local": "2017-03-09T18:00:00+0600",
#             "feels_like": 0,
#             "golf_category": "Poor",
#             "golf_index": 3,
#             "gust": null,
#             "hi": 3,
#             "icon_code": 28,
#             "icon_extd": 2800,
#             "mslp": 1020.9,
#             "num": 26,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 12,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 73,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 3,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.07,
#             "uv_warning": 0,
#             "vis": 11.0,
#             "wc": 0,
#             "wdir": 255,
#             "wdir_cardinal": "WSW",
#             "wspd": 12,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 71,
#             "day_ind": "N",
#             "dewpt": -1,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489064400,
#             "fcst_valid_local": "2017-03-09T19:00:00+0600",
#             "feels_like": -2,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": 1,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1021.4,
#             "num": 27,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 8,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 85,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 1,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 11.0,
#             "wc": -2,
#             "wdir": 282,
#             "wdir_cardinal": "WNW",
#             "wspd": 11,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 59,
#             "day_ind": "N",
#             "dewpt": -1,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489068000,
#             "fcst_valid_local": "2017-03-09T20:00:00+0600",
#             "feels_like": -5,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -1,
#             "icon_code": 29,
#             "icon_extd": 2900,
#             "mslp": 1022.0,
#             "num": 28,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 8,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 98,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -1,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 11.0,
#             "wc": -5,
#             "wdir": 313,
#             "wdir_cardinal": "NW",
#             "wspd": 12,
#             "wxman": "wx1610"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 51,
#             "day_ind": "N",
#             "dewpt": -2,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489071600,
#             "fcst_valid_local": "2017-03-09T21:00:00+0600",
#             "feels_like": -6,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -2,
#             "icon_code": 29,
#             "icon_extd": 2900,
#             "mslp": 1022.4,
#             "num": 29,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 8,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -2,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -6,
#             "wdir": 339,
#             "wdir_cardinal": "NNW",
#             "wspd": 13,
#             "wxman": "wx1610"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 57,
#             "day_ind": "N",
#             "dewpt": -3,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489075200,
#             "fcst_valid_local": "2017-03-09T22:00:00+0600",
#             "feels_like": -8,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -3,
#             "icon_code": 29,
#             "icon_extd": 2900,
#             "mslp": 1022.4,
#             "num": 30,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 8,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -3,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -8,
#             "wdir": 332,
#             "wdir_cardinal": "NNW",
#             "wspd": 13,
#             "wxman": "wx1610"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 70,
#             "day_ind": "N",
#             "dewpt": -3,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489078800,
#             "fcst_valid_local": "2017-03-09T23:00:00+0600",
#             "feels_like": -7,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -3,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1022.4,
#             "num": 31,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 8,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -3,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -7,
#             "wdir": 299,
#             "wdir_cardinal": "WNW",
#             "wspd": 11,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 77,
#             "day_ind": "N",
#             "dewpt": -3,
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489082400,
#             "fcst_valid_local": "2017-03-10T00:00:00+0600",
#             "feels_like": -8,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -3,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1022.5,
#             "num": 32,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 9,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -3,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -8,
#             "wdir": 250,
#             "wdir_cardinal": "WSW",
#             "wspd": 11,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 75,
#             "day_ind": "N",
#             "dewpt": -4,
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489086000,
#             "fcst_valid_local": "2017-03-10T01:00:00+0600",
#             "feels_like": -8,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -4,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1022.6,
#             "num": 33,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 9,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -4,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -8,
#             "wdir": 270,
#             "wdir_cardinal": "W",
#             "wspd": 10,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 68,
#             "day_ind": "N",
#             "dewpt": -4,
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489089600,
#             "fcst_valid_local": "2017-03-10T02:00:00+0600",
#             "feels_like": -9,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -4,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1022.7,
#             "num": 34,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 9,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -4,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -9,
#             "wdir": 261,
#             "wdir_cardinal": "W",
#             "wspd": 11,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 65,
#             "day_ind": "N",
#             "dewpt": -5,
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489093200,
#             "fcst_valid_local": "2017-03-10T03:00:00+0600",
#             "feels_like": -9,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -5,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1022.84,
#             "num": 35,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 11,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -5,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -9,
#             "wdir": 251,
#             "wdir_cardinal": "WSW",
#             "wspd": 12,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 66,
#             "day_ind": "N",
#             "dewpt": -5,
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489096800,
#             "fcst_valid_local": "2017-03-10T04:00:00+0600",
#             "feels_like": -10,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -5,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1023.0,
#             "num": 36,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 17,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -5,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -10,
#             "wdir": 249,
#             "wdir_cardinal": "WSW",
#             "wspd": 12,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 62,
#             "day_ind": "N",
#             "dewpt": -5,
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489100400,
#             "fcst_valid_local": "2017-03-10T05:00:00+0600",
#             "feels_like": -10,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -5,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1023.23,
#             "num": 37,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 16,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -5,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -10,
#             "wdir": 237,
#             "wdir_cardinal": "WSW",
#             "wspd": 12,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 60,
#             "day_ind": "N",
#             "dewpt": -6,
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489104000,
#             "fcst_valid_local": "2017-03-10T06:00:00+0600",
#             "feels_like": -10,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -6,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1023.4,
#             "num": 38,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 14,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -6,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -10,
#             "wdir": 235,
#             "wdir_cardinal": "SW",
#             "wspd": 10,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 61,
#             "day_ind": "N",
#             "dewpt": -6,
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489107600,
#             "fcst_valid_local": "2017-03-10T07:00:00+0600",
#             "feels_like": -10,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": -6,
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "mslp": 1023.8,
#             "num": 39,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 11,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -6,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -10,
#             "wdir": 236,
#             "wdir_cardinal": "SW",
#             "wspd": 11,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 65,
#             "day_ind": "D",
#             "dewpt": -6,
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489111200,
#             "fcst_valid_local": "2017-03-10T08:00:00+0600",
#             "feels_like": -11,
#             "golf_category": "Very Poor",
#             "golf_index": 0,
#             "gust": null,
#             "hi": -6,
#             "icon_code": 28,
#             "icon_extd": 2800,
#             "mslp": 1024.3,
#             "num": 40,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 10,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -6,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.06,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": -11,
#             "wdir": 237,
#             "wdir_cardinal": "WSW",
#             "wspd": 12,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 67,
#             "day_ind": "D",
#             "dewpt": -5,
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489114800,
#             "fcst_valid_local": "2017-03-10T09:00:00+0600",
#             "feels_like": -9,
#             "golf_category": "Very Poor",
#             "golf_index": 0,
#             "gust": null,
#             "hi": -5,
#             "icon_code": 28,
#             "icon_extd": 2800,
#             "mslp": 1024.83,
#             "num": 41,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 8,
#             "precip_type": "snow",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -5,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.32,
#             "uv_warning": 0,
#             "vis": 9.0,
#             "wc": -9,
#             "wdir": 231,
#             "wdir_cardinal": "SW",
#             "wspd": 12,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 67,
#             "day_ind": "D",
#             "dewpt": -4,
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489118400,
#             "fcst_valid_local": "2017-03-10T10:00:00+0600",
#             "feels_like": -9,
#             "golf_category": "Very Poor",
#             "golf_index": 0,
#             "gust": null,
#             "hi": -4,
#             "icon_code": 28,
#             "icon_extd": 2800,
#             "mslp": 1025.2,
#             "num": 42,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 7,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 96,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -4,
#             "uv_desc": "Low",
#             "uv_index": 1,
#             "uv_index_raw": 0.9,
#             "uv_warning": 0,
#             "vis": 12.0,
#             "wc": -9,
#             "wdir": 233,
#             "wdir_cardinal": "SW",
#             "wspd": 12,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 67,
#             "day_ind": "D",
#             "dewpt": -4,
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489122000,
#             "fcst_valid_local": "2017-03-10T11:00:00+0600",
#             "feels_like": -7,
#             "golf_category": "Very Poor",
#             "golf_index": 1,
#             "gust": null,
#             "hi": -2,
#             "icon_code": 28,
#             "icon_extd": 2800,
#             "mslp": 1025.4,
#             "num": 43,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 6,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 85,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -2,
#             "uv_desc": "Low",
#             "uv_index": 2,
#             "uv_index_raw": 1.63,
#             "uv_warning": 0,
#             "vis": 15.0,
#             "wc": -7,
#             "wdir": 236,
#             "wdir_cardinal": "SW",
#             "wspd": 13,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 67,
#             "day_ind": "D",
#             "dewpt": -5,
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489125600,
#             "fcst_valid_local": "2017-03-10T12:00:00+0600",
#             "feels_like": -6,
#             "golf_category": "Very Poor",
#             "golf_index": 1,
#             "gust": null,
#             "hi": -1,
#             "icon_code": 28,
#             "icon_extd": 2800,
#             "mslp": 1025.5,
#             "num": 44,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 6,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 77,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -1,
#             "uv_desc": "Low",
#             "uv_index": 2,
#             "uv_index_raw": 2.24,
#             "uv_warning": 0,
#             "vis": 16.0,
#             "wc": -6,
#             "wdir": 236,
#             "wdir_cardinal": "SW",
#             "wspd": 13,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 70,
#             "day_ind": "D",
#             "dewpt": -5,
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489129200,
#             "fcst_valid_local": "2017-03-10T13:00:00+0600",
#             "feels_like": -5,
#             "golf_category": "Very Poor",
#             "golf_index": 1,
#             "gust": null,
#             "hi": -1,
#             "icon_code": 28,
#             "icon_extd": 2800,
#             "mslp": 1025.5,
#             "num": 45,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 4,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 70,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": -1,
#             "uv_desc": "Moderate",
#             "uv_index": 3,
#             "uv_index_raw": 2.52,
#             "uv_warning": 0,
#             "vis": 16.0,
#             "wc": -5,
#             "wdir": 236,
#             "wdir_cardinal": "SW",
#             "wspd": 15,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 73,
#             "day_ind": "D",
#             "dewpt": -6,
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489132800,
#             "fcst_valid_local": "2017-03-10T14:00:00+0600",
#             "feels_like": -5,
#             "golf_category": "Very Poor",
#             "golf_index": 2,
#             "gust": null,
#             "hi": 0,
#             "icon_code": 28,
#             "icon_extd": 2800,
#             "mslp": 1025.3,
#             "num": 46,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 4,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 66,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 0,
#             "uv_desc": "Low",
#             "uv_index": 2,
#             "uv_index_raw": 2.36,
#             "uv_warning": 0,
#             "vis": 16.0,
#             "wc": -5,
#             "wdir": 233,
#             "wdir_cardinal": "SW",
#             "wspd": 16,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 76,
#             "day_ind": "D",
#             "dewpt": -6,
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489136400,
#             "fcst_valid_local": "2017-03-10T15:00:00+0600",
#             "feels_like": -4,
#             "golf_category": "Very Poor",
#             "golf_index": 2,
#             "gust": null,
#             "hi": 1,
#             "icon_code": 28,
#             "icon_extd": 2800,
#             "mslp": 1025.2,
#             "num": 47,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 3,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 62,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 1,
#             "uv_desc": "Low",
#             "uv_index": 1,
#             "uv_index_raw": 1.46,
#             "uv_warning": 0,
#             "vis": 16.0,
#             "wc": -4,
#             "wdir": 235,
#             "wdir_cardinal": "SW",
#             "wspd": 16,
#             "wxman": "wx1210"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 75,
#             "day_ind": "D",
#             "dewpt": -6,
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489140000,
#             "fcst_valid_local": "2017-03-10T16:00:00+0600",
#             "feels_like": -3,
#             "golf_category": "Very Poor",
#             "golf_index": 2,
#             "gust": null,
#             "hi": 1,
#             "icon_code": 28,
#             "icon_extd": 2800,
#             "mslp": 1025.4,
#             "num": 48,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 4,
#             "precip_type": "precip",
#             "qpf": 0.0,
#             "rh": 61,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 1,
#             "uv_desc": "Low",
#             "uv_index": 1,
#             "uv_index_raw": 1.1,
#             "uv_warning": 0,
#             "vis": 16.0,
#             "wc": -3,
#             "wdir": 239,
#             "wdir_cardinal": "WSW",
#             "wspd": 17,
#             "wxman": "wx1210"
#         }
#     ],
#     "metadata": {
#         "expire_time_gmt": 1488969471,
#         "language": "en-US",
#         "latitude": 45.42,
#         "longitude": 75.69,
#         "status_code": 200,
#         "transaction_id": "1488968870990:-67158222",
#         "units": "m",
#         "version": "1"
#     }
# }

# %% [markdown]
# ### You can also issue a GET operation in your application to retrieve a 48-hour hourly forecast data for a postal code.
#
# Note: You can supply a postal code for the supported country codes United States (US), United Kingdom (GB), France (FR), Germany (DE), or Italy (IT) only.

# %%
print_api_resp("api/weather/v1/location/97229%3A4%3AUS/forecast/hourly/48hour.json?units=m&language=en-US",credentials_1)
# Out:
# {
#     "forecasts": [
#         {
#             "class": "fod_short_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 6,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488969976,
#             "fcst_valid": 1488970800,
#             "fcst_valid_local": "2017-03-08T03:00:00-0800",
#             "feels_like": 6,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": 6,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1020.1,
#             "num": 1,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 10,
#             "precip_type": "rain",
#             "qpf": 0.0,
#             "rh": 96,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 6,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": 6,
#             "wdir": 199,
#             "wdir_cardinal": "SSW",
#             "wspd": 3,
#             "wxman": "wx1250"
#         },
#         {
#             "class": "fod_short_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 5,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488969976,
#             "fcst_valid": 1488974400,
#             "fcst_valid_local": "2017-03-08T04:00:00-0800",
#             "feels_like": 6,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": 6,
#             "icon_code": 11,
#             "icon_extd": 4600,
#             "mslp": 1021.0,
#             "num": 2,
#             "phrase_12char": "Few Showers",
#             "phrase_22char": "Few Showers",
#             "phrase_32char": "Few Showers",
#             "pop": 33,
#             "precip_type": "rain",
#             "qpf": 0.15,
#             "rh": 96,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Few",
#             "subphrase_pt2": "Showers",
#             "subphrase_pt3": "",
#             "temp": 6,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": 6,
#             "wdir": 201,
#             "wdir_cardinal": "SSW",
#             "wspd": 4,
#             "wxman": "wx2050"
#         },
#         {
#             "class": "fod_short_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 5,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488969976,
#             "fcst_valid": 1488978000,
#             "fcst_valid_local": "2017-03-08T05:00:00-0800",
#             "feels_like": 6,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": 6,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1021.1,
#             "num": 3,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 42,
#             "precip_type": "rain",
#             "qpf": 0.4,
#             "rh": 96,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 6,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 7.0,
#             "wc": 6,
#             "wdir": 192,
#             "wdir_cardinal": "S",
#             "wspd": 4,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_short_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 5,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488969976,
#             "fcst_valid": 1488981600,
#             "fcst_valid_local": "2017-03-08T06:00:00-0800",
#             "feels_like": 6,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": 6,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1021.4,
#             "num": 4,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 40,
#             "precip_type": "rain",
#             "qpf": 0.18,
#             "rh": 94,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 6,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 7.0,
#             "wc": 6,
#             "wdir": 180,
#             "wdir_cardinal": "S",
#             "wspd": 4,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_short_range_hourly",
#             "clds": 99,
#             "day_ind": "D",
#             "dewpt": 5,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488969976,
#             "fcst_valid": 1488985200,
#             "fcst_valid_local": "2017-03-08T07:00:00-0800",
#             "feels_like": 5,
#             "golf_category": "Very Poor",
#             "golf_index": 1,
#             "gust": null,
#             "hi": 6,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1021.6,
#             "num": 5,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 50,
#             "precip_type": "rain",
#             "qpf": 0.42,
#             "rh": 94,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 6,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.03,
#             "uv_warning": 0,
#             "vis": 6.0,
#             "wc": 5,
#             "wdir": 180,
#             "wdir_cardinal": "S",
#             "wspd": 5,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_short_range_hourly",
#             "clds": 99,
#             "day_ind": "D",
#             "dewpt": 5,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488969976,
#             "fcst_valid": 1488988800,
#             "fcst_valid_local": "2017-03-08T08:00:00-0800",
#             "feels_like": 4,
#             "golf_category": "Very Poor",
#             "golf_index": 1,
#             "gust": null,
#             "hi": 5,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1021.8,
#             "num": 6,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 46,
#             "precip_type": "rain",
#             "qpf": 0.37,
#             "rh": 95,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 5,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.12,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": 4,
#             "wdir": 182,
#             "wdir_cardinal": "S",
#             "wspd": 6,
#             "wxman": "wx2510"
#         },
#         {
#             "class": "fod_short_range_hourly",
#             "clds": 99,
#             "day_ind": "D",
#             "dewpt": 5,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488969976,
#             "fcst_valid": 1488992400,
#             "fcst_valid_local": "2017-03-08T09:00:00-0800",
#             "feels_like": 4,
#             "golf_category": "Very Poor",
#             "golf_index": 1,
#             "gust": null,
#             "hi": 5,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1022.0,
#             "num": 7,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 50,
#             "precip_type": "rain",
#             "qpf": 0.24,
#             "rh": 95,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 5,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.39,
#             "uv_warning": 0,
#             "vis": 11.0,
#             "wc": 4,
#             "wdir": 186,
#             "wdir_cardinal": "S",
#             "wspd": 7,
#             "wxman": "wx2510"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 99,
#             "day_ind": "D",
#             "dewpt": 4,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1488996000,
#             "fcst_valid_local": "2017-03-08T10:00:00-0800",
#             "feels_like": 4,
#             "golf_category": "Very Poor",
#             "golf_index": 1,
#             "gust": null,
#             "hi": 5,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1022.0,
#             "num": 8,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 57,
#             "precip_type": "rain",
#             "qpf": 0.3,
#             "rh": 93,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 5,
#             "uv_desc": "Low",
#             "uv_index": 1,
#             "uv_index_raw": 0.77,
#             "uv_warning": 0,
#             "vis": 12.0,
#             "wc": 4,
#             "wdir": 187,
#             "wdir_cardinal": "S",
#             "wspd": 8,
#             "wxman": "wx2510"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 99,
#             "day_ind": "D",
#             "dewpt": 4,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1488999600,
#             "fcst_valid_local": "2017-03-08T11:00:00-0800",
#             "feels_like": 4,
#             "golf_category": "Very Poor",
#             "golf_index": 1,
#             "gust": null,
#             "hi": 6,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1021.7,
#             "num": 9,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 59,
#             "precip_type": "rain",
#             "qpf": 0.4,
#             "rh": 91,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 6,
#             "uv_desc": "Low",
#             "uv_index": 1,
#             "uv_index_raw": 1.12,
#             "uv_warning": 0,
#             "vis": 13.0,
#             "wc": 4,
#             "wdir": 191,
#             "wdir_cardinal": "S",
#             "wspd": 9,
#             "wxman": "wx2510"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 99,
#             "day_ind": "D",
#             "dewpt": 4,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489003200,
#             "fcst_valid_local": "2017-03-08T12:00:00-0800",
#             "feels_like": 5,
#             "golf_category": "Very Poor",
#             "golf_index": 2,
#             "gust": null,
#             "hi": 6,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1021.5,
#             "num": 10,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 55,
#             "precip_type": "rain",
#             "qpf": 0.4,
#             "rh": 88,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 6,
#             "uv_desc": "Low",
#             "uv_index": 1,
#             "uv_index_raw": 1.32,
#             "uv_warning": 0,
#             "vis": 13.0,
#             "wc": 5,
#             "wdir": 187,
#             "wdir_cardinal": "S",
#             "wspd": 9,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "D",
#             "dewpt": 5,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489006800,
#             "fcst_valid_local": "2017-03-08T13:00:00-0800",
#             "feels_like": 5,
#             "golf_category": "Very Poor",
#             "golf_index": 2,
#             "gust": null,
#             "hi": 7,
#             "icon_code": 11,
#             "icon_extd": 1201,
#             "mslp": 1021.1,
#             "num": 11,
#             "phrase_12char": "Light Rain",
#             "phrase_22char": "Light Rain",
#             "phrase_32char": "Light Rain",
#             "pop": 62,
#             "precip_type": "rain",
#             "qpf": 0.6,
#             "rh": 86,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Light",
#             "subphrase_pt2": "Rain",
#             "subphrase_pt3": "",
#             "temp": 7,
#             "uv_desc": "Low",
#             "uv_index": 1,
#             "uv_index_raw": 1.29,
#             "uv_warning": 0,
#             "vis": 12.0,
#             "wc": 5,
#             "wdir": 188,
#             "wdir_cardinal": "S",
#             "wspd": 8,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "D",
#             "dewpt": 5,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489010400,
#             "fcst_valid_local": "2017-03-08T14:00:00-0800",
#             "feels_like": 6,
#             "golf_category": "Very Poor",
#             "golf_index": 2,
#             "gust": null,
#             "hi": 7,
#             "icon_code": 11,
#             "icon_extd": 1201,
#             "mslp": 1020.5,
#             "num": 12,
#             "phrase_12char": "Light Rain",
#             "phrase_22char": "Light Rain",
#             "phrase_32char": "Light Rain",
#             "pop": 60,
#             "precip_type": "rain",
#             "qpf": 0.4,
#             "rh": 85,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Light",
#             "subphrase_pt2": "Rain",
#             "subphrase_pt3": "",
#             "temp": 7,
#             "uv_desc": "Low",
#             "uv_index": 1,
#             "uv_index_raw": 1.04,
#             "uv_warning": 0,
#             "vis": 12.0,
#             "wc": 6,
#             "wdir": 186,
#             "wdir_cardinal": "S",
#             "wspd": 8,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "D",
#             "dewpt": 5,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489014000,
#             "fcst_valid_local": "2017-03-08T15:00:00-0800",
#             "feels_like": 6,
#             "golf_category": "Very Poor",
#             "golf_index": 2,
#             "gust": null,
#             "hi": 7,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1019.8,
#             "num": 13,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 56,
#             "precip_type": "rain",
#             "qpf": 0.3,
#             "rh": 87,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 7,
#             "uv_desc": "Low",
#             "uv_index": 1,
#             "uv_index_raw": 0.67,
#             "uv_warning": 0,
#             "vis": 10.0,
#             "wc": 6,
#             "wdir": 180,
#             "wdir_cardinal": "S",
#             "wspd": 7,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "D",
#             "dewpt": 6,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489017600,
#             "fcst_valid_local": "2017-03-08T16:00:00-0800",
#             "feels_like": 7,
#             "golf_category": "Very Poor",
#             "golf_index": 2,
#             "gust": null,
#             "hi": 8,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1019.1,
#             "num": 14,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 50,
#             "precip_type": "rain",
#             "qpf": 0.3,
#             "rh": 88,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.31,
#             "uv_warning": 0,
#             "vis": 9.0,
#             "wc": 7,
#             "wdir": 163,
#             "wdir_cardinal": "SSE",
#             "wspd": 6,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "D",
#             "dewpt": 7,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489021200,
#             "fcst_valid_local": "2017-03-08T17:00:00-0800",
#             "feels_like": 8,
#             "golf_category": "Very Poor",
#             "golf_index": 2,
#             "gust": null,
#             "hi": 8,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1018.6,
#             "num": 15,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 52,
#             "precip_type": "rain",
#             "qpf": 0.3,
#             "rh": 89,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.03,
#             "uv_warning": 0,
#             "vis": 6.0,
#             "wc": 8,
#             "wdir": 166,
#             "wdir_cardinal": "SSE",
#             "wspd": 6,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "D",
#             "dewpt": 7,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489024800,
#             "fcst_valid_local": "2017-03-08T18:00:00-0800",
#             "feels_like": 8,
#             "golf_category": "Very Poor",
#             "golf_index": 2,
#             "gust": null,
#             "hi": 9,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1018.0,
#             "num": 16,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 58,
#             "precip_type": "rain",
#             "qpf": 0.2,
#             "rh": 92,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 9,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.02,
#             "uv_warning": 0,
#             "vis": 4.8,
#             "wc": 8,
#             "wdir": 169,
#             "wdir_cardinal": "S",
#             "wspd": 5,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 8,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489028400,
#             "fcst_valid_local": "2017-03-08T19:00:00-0800",
#             "feels_like": 8,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": 9,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1017.6,
#             "num": 17,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 41,
#             "precip_type": "rain",
#             "qpf": 0.2,
#             "rh": 96,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 9,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 4.8,
#             "wc": 8,
#             "wdir": 177,
#             "wdir_cardinal": "S",
#             "wspd": 5,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 8,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489032000,
#             "fcst_valid_local": "2017-03-08T20:00:00-0800",
#             "feels_like": 8,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": 9,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1017.3,
#             "num": 18,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 41,
#             "precip_type": "rain",
#             "qpf": 0.2,
#             "rh": 97,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 9,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 4.8,
#             "wc": 8,
#             "wdir": 177,
#             "wdir_cardinal": "S",
#             "wspd": 6,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 8,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489035600,
#             "fcst_valid_local": "2017-03-08T21:00:00-0800",
#             "feels_like": 8,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": 9,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1017.2,
#             "num": 19,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 41,
#             "precip_type": "rain",
#             "qpf": 0.2,
#             "rh": 97,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 9,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 4.8,
#             "wc": 8,
#             "wdir": 183,
#             "wdir_cardinal": "S",
#             "wspd": 5,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 8,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489039200,
#             "fcst_valid_local": "2017-03-08T22:00:00-0800",
#             "feels_like": 7,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": 8,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1017.0,
#             "num": 20,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 39,
#             "precip_type": "rain",
#             "qpf": 0.1,
#             "rh": 99,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 4.8,
#             "wc": 7,
#             "wdir": 193,
#             "wdir_cardinal": "SSW",
#             "wspd": 6,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 8,
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489042800,
#             "fcst_valid_local": "2017-03-08T23:00:00-0800",
#             "feels_like": 7,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": 8,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1017.0,
#             "num": 21,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 41,
#             "precip_type": "rain",
#             "qpf": 0.1,
#             "rh": 99,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 4.8,
#             "wc": 7,
#             "wdir": 199,
#             "wdir_cardinal": "SSW",
#             "wspd": 7,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 8,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489046400,
#             "fcst_valid_local": "2017-03-09T00:00:00-0800",
#             "feels_like": 7,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": 8,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1017.3,
#             "num": 22,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 42,
#             "precip_type": "rain",
#             "qpf": 0.1,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 4.8,
#             "wc": 7,
#             "wdir": 203,
#             "wdir_cardinal": "SSW",
#             "wspd": 8,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 8,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489050000,
#             "fcst_valid_local": "2017-03-09T01:00:00-0800",
#             "feels_like": 7,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": 8,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1017.7,
#             "num": 23,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 11,
#             "precip_type": "rain",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": 7,
#             "wdir": 198,
#             "wdir_cardinal": "SSW",
#             "wspd": 8,
#             "wxman": "wx1250"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 8,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489053600,
#             "fcst_valid_local": "2017-03-09T02:00:00-0800",
#             "feels_like": 7,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": 8,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1017.9,
#             "num": 24,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 12,
#             "precip_type": "rain",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": 7,
#             "wdir": 201,
#             "wdir_cardinal": "SSW",
#             "wspd": 7,
#             "wxman": "wx1250"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 8,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489057200,
#             "fcst_valid_local": "2017-03-09T03:00:00-0800",
#             "feels_like": 7,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": 8,
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "mslp": 1017.9,
#             "num": 25,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 12,
#             "precip_type": "rain",
#             "qpf": 0.0,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": 7,
#             "wdir": 195,
#             "wdir_cardinal": "SSW",
#             "wspd": 7,
#             "wxman": "wx1250"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 8,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489060800,
#             "fcst_valid_local": "2017-03-09T04:00:00-0800",
#             "feels_like": 7,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": 8,
#             "icon_code": 11,
#             "icon_extd": 1201,
#             "mslp": 1018.1,
#             "num": 26,
#             "phrase_12char": "Light Rain",
#             "phrase_22char": "Light Rain",
#             "phrase_32char": "Light Rain",
#             "pop": 60,
#             "precip_type": "rain",
#             "qpf": 0.3,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Light",
#             "subphrase_pt2": "Rain",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 4.8,
#             "wc": 7,
#             "wdir": 200,
#             "wdir_cardinal": "SSW",
#             "wspd": 6,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 8,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489064400,
#             "fcst_valid_local": "2017-03-09T05:00:00-0800",
#             "feels_like": 8,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": 8,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1018.2,
#             "num": 27,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 58,
#             "precip_type": "rain",
#             "qpf": 0.3,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 4.8,
#             "wc": 8,
#             "wdir": 198,
#             "wdir_cardinal": "SSW",
#             "wspd": 5,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 8,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489068000,
#             "fcst_valid_local": "2017-03-09T06:00:00-0800",
#             "feels_like": 8,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": null,
#             "hi": 8,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1018.4,
#             "num": 28,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 49,
#             "precip_type": "rain",
#             "qpf": 0.3,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 4.8,
#             "wc": 8,
#             "wdir": 180,
#             "wdir_cardinal": "S",
#             "wspd": 4,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "D",
#             "dewpt": 8,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489071600,
#             "fcst_valid_local": "2017-03-09T07:00:00-0800",
#             "feels_like": 8,
#             "golf_category": "Very Poor",
#             "golf_index": 0,
#             "gust": null,
#             "hi": 8,
#             "icon_code": 12,
#             "icon_extd": 1200,
#             "mslp": 1018.4,
#             "num": 29,
#             "phrase_12char": "Rain",
#             "phrase_22char": "Rain",
#             "phrase_32char": "Rain",
#             "pop": 88,
#             "precip_type": "rain",
#             "qpf": 1.5,
#             "rh": 99,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Rain",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.01,
#             "uv_warning": 0,
#             "vis": 3.2,
#             "wc": 8,
#             "wdir": 133,
#             "wdir_cardinal": "SE",
#             "wspd": 3,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "D",
#             "dewpt": 8,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489075200,
#             "fcst_valid_local": "2017-03-09T08:00:00-0800",
#             "feels_like": 8,
#             "golf_category": "Very Poor",
#             "golf_index": 0,
#             "gust": null,
#             "hi": 8,
#             "icon_code": 12,
#             "icon_extd": 1200,
#             "mslp": 1018.4,
#             "num": 30,
#             "phrase_12char": "Rain",
#             "phrase_22char": "Rain",
#             "phrase_32char": "Rain",
#             "pop": 91,
#             "precip_type": "rain",
#             "qpf": 1.6,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Rain",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.06,
#             "uv_warning": 0,
#             "vis": 3.5,
#             "wc": 8,
#             "wdir": 56,
#             "wdir_cardinal": "NE",
#             "wspd": 3,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "D",
#             "dewpt": 8,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489078800,
#             "fcst_valid_local": "2017-03-09T09:00:00-0800",
#             "feels_like": 8,
#             "golf_category": "Very Poor",
#             "golf_index": 0,
#             "gust": null,
#             "hi": 8,
#             "icon_code": 12,
#             "icon_extd": 1200,
#             "mslp": 1018.4,
#             "num": 31,
#             "phrase_12char": "Rain",
#             "phrase_22char": "Rain",
#             "phrase_32char": "Rain",
#             "pop": 99,
#             "precip_type": "rain",
#             "qpf": 1.8,
#             "rh": 100,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Rain",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.18,
#             "uv_warning": 0,
#             "vis": 4.3,
#             "wc": 8,
#             "wdir": 63,
#             "wdir_cardinal": "ENE",
#             "wspd": 3,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "D",
#             "dewpt": 8,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489082400,
#             "fcst_valid_local": "2017-03-09T10:00:00-0800",
#             "feels_like": 7,
#             "golf_category": "Very Poor",
#             "golf_index": 0,
#             "gust": null,
#             "hi": 8,
#             "icon_code": 12,
#             "icon_extd": 1200,
#             "mslp": 1018.0,
#             "num": 32,
#             "phrase_12char": "Rain",
#             "phrase_22char": "Rain",
#             "phrase_32char": "Rain",
#             "pop": 98,
#             "precip_type": "rain",
#             "qpf": 1.7,
#             "rh": 99,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Rain",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.36,
#             "uv_warning": 0,
#             "vis": 4.7,
#             "wc": 7,
#             "wdir": 85,
#             "wdir_cardinal": "E",
#             "wspd": 5,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "D",
#             "dewpt": 8,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489086000,
#             "fcst_valid_local": "2017-03-09T11:00:00-0800",
#             "feels_like": 7,
#             "golf_category": "Very Poor",
#             "golf_index": 0,
#             "gust": null,
#             "hi": 8,
#             "icon_code": 12,
#             "icon_extd": 1200,
#             "mslp": 1017.5,
#             "num": 33,
#             "phrase_12char": "Rain",
#             "phrase_22char": "Rain",
#             "phrase_32char": "Rain",
#             "pop": 98,
#             "precip_type": "rain",
#             "qpf": 1.5,
#             "rh": 97,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Rain",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "uv_desc": "Low",
#             "uv_index": 1,
#             "uv_index_raw": 0.52,
#             "uv_warning": 0,
#             "vis": 4.7,
#             "wc": 7,
#             "wdir": 104,
#             "wdir_cardinal": "ESE",
#             "wspd": 7,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "D",
#             "dewpt": 8,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489089600,
#             "fcst_valid_local": "2017-03-09T12:00:00-0800",
#             "feels_like": 7,
#             "golf_category": "Very Poor",
#             "golf_index": 0,
#             "gust": null,
#             "hi": 9,
#             "icon_code": 12,
#             "icon_extd": 1200,
#             "mslp": 1016.9,
#             "num": 34,
#             "phrase_12char": "Rain",
#             "phrase_22char": "Rain",
#             "phrase_32char": "Rain",
#             "pop": 98,
#             "precip_type": "rain",
#             "qpf": 1.6,
#             "rh": 97,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Rain",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 9,
#             "uv_desc": "Low",
#             "uv_index": 1,
#             "uv_index_raw": 0.61,
#             "uv_warning": 0,
#             "vis": 4.6,
#             "wc": 7,
#             "wdir": 144,
#             "wdir_cardinal": "SE",
#             "wspd": 10,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "D",
#             "dewpt": 8,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489093200,
#             "fcst_valid_local": "2017-03-09T13:00:00-0800",
#             "feels_like": 7,
#             "golf_category": "Very Poor",
#             "golf_index": 0,
#             "gust": null,
#             "hi": 9,
#             "icon_code": 12,
#             "icon_extd": 1200,
#             "mslp": 1016.3,
#             "num": 35,
#             "phrase_12char": "Rain",
#             "phrase_22char": "Rain",
#             "phrase_32char": "Rain",
#             "pop": 97,
#             "precip_type": "rain",
#             "qpf": 1.2,
#             "rh": 97,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Rain",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 9,
#             "uv_desc": "Low",
#             "uv_index": 1,
#             "uv_index_raw": 0.6,
#             "uv_warning": 0,
#             "vis": 4.2,
#             "wc": 7,
#             "wdir": 151,
#             "wdir_cardinal": "SSE",
#             "wspd": 10,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "D",
#             "dewpt": 9,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489096800,
#             "fcst_valid_local": "2017-03-09T14:00:00-0800",
#             "feels_like": 8,
#             "golf_category": "Very Poor",
#             "golf_index": 0,
#             "gust": null,
#             "hi": 10,
#             "icon_code": 12,
#             "icon_extd": 1200,
#             "mslp": 1015.4,
#             "num": 36,
#             "phrase_12char": "Rain",
#             "phrase_22char": "Rain",
#             "phrase_32char": "Rain",
#             "pop": 93,
#             "precip_type": "rain",
#             "qpf": 1.2,
#             "rh": 93,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Rain",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 10,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.48,
#             "uv_warning": 0,
#             "vis": 4.5,
#             "wc": 8,
#             "wdir": 171,
#             "wdir_cardinal": "S",
#             "wspd": 13,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "D",
#             "dewpt": 9,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489100400,
#             "fcst_valid_local": "2017-03-09T15:00:00-0800",
#             "feels_like": 8,
#             "golf_category": "Very Poor",
#             "golf_index": 0,
#             "gust": 31,
#             "hi": 10,
#             "icon_code": 12,
#             "icon_extd": 1200,
#             "mslp": 1014.6,
#             "num": 37,
#             "phrase_12char": "Rain",
#             "phrase_22char": "Rain",
#             "phrase_32char": "Rain",
#             "pop": 87,
#             "precip_type": "rain",
#             "qpf": 1.5,
#             "rh": 92,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Rain",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 10,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.31,
#             "uv_warning": 0,
#             "vis": 6.0,
#             "wc": 8,
#             "wdir": 187,
#             "wdir_cardinal": "S",
#             "wspd": 16,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "D",
#             "dewpt": 9,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489104000,
#             "fcst_valid_local": "2017-03-09T16:00:00-0800",
#             "feels_like": 9,
#             "golf_category": "Very Poor",
#             "golf_index": 0,
#             "gust": 34,
#             "hi": 11,
#             "icon_code": 12,
#             "icon_extd": 1200,
#             "mslp": 1014.0,
#             "num": 38,
#             "phrase_12char": "Rain",
#             "phrase_22char": "Rain",
#             "phrase_32char": "Rain",
#             "pop": 85,
#             "precip_type": "rain",
#             "qpf": 1.7,
#             "rh": 89,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Rain",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 11,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.14,
#             "uv_warning": 0,
#             "vis": 6.0,
#             "wc": 9,
#             "wdir": 190,
#             "wdir_cardinal": "S",
#             "wspd": 17,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "D",
#             "dewpt": 10,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489107600,
#             "fcst_valid_local": "2017-03-09T17:00:00-0800",
#             "feels_like": 10,
#             "golf_category": "Very Poor",
#             "golf_index": 1,
#             "gust": 38,
#             "hi": 12,
#             "icon_code": 12,
#             "icon_extd": 1200,
#             "mslp": 1013.7,
#             "num": 39,
#             "phrase_12char": "Rain",
#             "phrase_22char": "Rain",
#             "phrase_32char": "Rain",
#             "pop": 80,
#             "precip_type": "rain",
#             "qpf": 1.4,
#             "rh": 88,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Rain",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 12,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.08,
#             "uv_warning": 0,
#             "vis": 6.0,
#             "wc": 10,
#             "wdir": 198,
#             "wdir_cardinal": "SSW",
#             "wspd": 19,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "D",
#             "dewpt": 10,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489111200,
#             "fcst_valid_local": "2017-03-09T18:00:00-0800",
#             "feels_like": 9,
#             "golf_category": "Very Poor",
#             "golf_index": 1,
#             "gust": 40,
#             "hi": 12,
#             "icon_code": 12,
#             "icon_extd": 1200,
#             "mslp": 1013.3,
#             "num": 40,
#             "phrase_12char": "Rain",
#             "phrase_22char": "Rain",
#             "phrase_32char": "Rain",
#             "pop": 84,
#             "precip_type": "rain",
#             "qpf": 1.4,
#             "rh": 90,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Rain",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 12,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0.04,
#             "uv_warning": 0,
#             "vis": 7.0,
#             "wc": 9,
#             "wdir": 198,
#             "wdir_cardinal": "SSW",
#             "wspd": 20,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 10,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489114800,
#             "fcst_valid_local": "2017-03-09T19:00:00-0800",
#             "feels_like": 9,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": 43,
#             "hi": 11,
#             "icon_code": 12,
#             "icon_extd": 1200,
#             "mslp": 1013.2,
#             "num": 41,
#             "phrase_12char": "Rain",
#             "phrase_22char": "Rain",
#             "phrase_32char": "Rain",
#             "pop": 93,
#             "precip_type": "rain",
#             "qpf": 0.9,
#             "rh": 92,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Rain",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 11,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 7.0,
#             "wc": 9,
#             "wdir": 200,
#             "wdir_cardinal": "SSW",
#             "wspd": 22,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 10,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489118400,
#             "fcst_valid_local": "2017-03-09T20:00:00-0800",
#             "feels_like": 9,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": 45,
#             "hi": 11,
#             "icon_code": 12,
#             "icon_extd": 1200,
#             "mslp": 1013.2,
#             "num": 42,
#             "phrase_12char": "Rain",
#             "phrase_22char": "Rain",
#             "phrase_32char": "Rain",
#             "pop": 91,
#             "precip_type": "rain",
#             "qpf": 0.9,
#             "rh": 92,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Rain",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 11,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": 9,
#             "wdir": 198,
#             "wdir_cardinal": "SSW",
#             "wspd": 23,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 100,
#             "day_ind": "N",
#             "dewpt": 10,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489122000,
#             "fcst_valid_local": "2017-03-09T21:00:00-0800",
#             "feels_like": 9,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": 42,
#             "hi": 11,
#             "icon_code": 12,
#             "icon_extd": 1200,
#             "mslp": 1013.2,
#             "num": 43,
#             "phrase_12char": "Rain",
#             "phrase_22char": "Rain",
#             "phrase_32char": "Rain",
#             "pop": 87,
#             "precip_type": "rain",
#             "qpf": 0.9,
#             "rh": 91,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Rain",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 11,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": 9,
#             "wdir": 198,
#             "wdir_cardinal": "SSW",
#             "wspd": 22,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 99,
#             "day_ind": "N",
#             "dewpt": 9,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489125600,
#             "fcst_valid_local": "2017-03-09T22:00:00-0800",
#             "feels_like": 8,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": 42,
#             "hi": 11,
#             "icon_code": 11,
#             "icon_extd": 4600,
#             "mslp": 1013.2,
#             "num": 44,
#             "phrase_12char": "Few Showers",
#             "phrase_22char": "Few Showers",
#             "phrase_32char": "Few Showers",
#             "pop": 33,
#             "precip_type": "rain",
#             "qpf": 0.1,
#             "rh": 90,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Few",
#             "subphrase_pt2": "Showers",
#             "subphrase_pt3": "",
#             "temp": 11,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": 8,
#             "wdir": 197,
#             "wdir_cardinal": "SSW",
#             "wspd": 22,
#             "wxman": "wx2050"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 97,
#             "day_ind": "N",
#             "dewpt": 9,
#             "dow": "Thursday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489129200,
#             "fcst_valid_local": "2017-03-09T23:00:00-0800",
#             "feels_like": 8,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": 46,
#             "hi": 11,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1013.2,
#             "num": 45,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 39,
#             "precip_type": "rain",
#             "qpf": 0.2,
#             "rh": 88,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 11,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 8.0,
#             "wc": 8,
#             "wdir": 200,
#             "wdir_cardinal": "SSW",
#             "wspd": 24,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 93,
#             "day_ind": "N",
#             "dewpt": 9,
#             "dow": "Friday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489132800,
#             "fcst_valid_local": "2017-03-10T00:00:00-0800",
#             "feels_like": 8,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": 47,
#             "hi": 11,
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "mslp": 1013.0,
#             "num": 46,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 40,
#             "precip_type": "rain",
#             "qpf": 0.2,
#             "rh": 88,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 11,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 9.0,
#             "wc": 8,
#             "wdir": 198,
#             "wdir_cardinal": "SSW",
#             "wspd": 25,
#             "wxman": "wx2550"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 92,
#             "day_ind": "N",
#             "dewpt": 8,
#             "dow": "Friday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489136400,
#             "fcst_valid_local": "2017-03-10T01:00:00-0800",
#             "feels_like": 7,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": 49,
#             "hi": 10,
#             "icon_code": 11,
#             "icon_extd": 4600,
#             "mslp": 1012.9,
#             "num": 47,
#             "phrase_12char": "Few Showers",
#             "phrase_22char": "Few Showers",
#             "phrase_32char": "Few Showers",
#             "pop": 33,
#             "precip_type": "rain",
#             "qpf": 0.1,
#             "rh": 87,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Few",
#             "subphrase_pt2": "Showers",
#             "subphrase_pt3": "",
#             "temp": 10,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 10.0,
#             "wc": 7,
#             "wdir": 197,
#             "wdir_cardinal": "SSW",
#             "wspd": 26,
#             "wxman": "wx2050"
#         },
#         {
#             "class": "fod_long_range_hourly",
#             "clds": 94,
#             "day_ind": "N",
#             "dewpt": 8,
#             "dow": "Friday",
#             "expire_time_gmt": 1488971176,
#             "fcst_valid": 1489140000,
#             "fcst_valid_local": "2017-03-10T02:00:00-0800",
#             "feels_like": 7,
#             "golf_category": "",
#             "golf_index": null,
#             "gust": 50,
#             "hi": 10,
#             "icon_code": 11,
#             "icon_extd": 4600,
#             "mslp": 1012.9,
#             "num": 48,
#             "phrase_12char": "Few Showers",
#             "phrase_22char": "Few Showers",
#             "phrase_32char": "Few Showers",
#             "pop": 34,
#             "precip_type": "rain",
#             "qpf": 0.1,
#             "rh": 86,
#             "severity": 1,
#             "snow_qpf": 0.0,
#             "subphrase_pt1": "Few",
#             "subphrase_pt2": "Showers",
#             "subphrase_pt3": "",
#             "temp": 10,
#             "uv_desc": "Low",
#             "uv_index": 0,
#             "uv_index_raw": 0,
#             "uv_warning": 0,
#             "vis": 11.0,
#             "wc": 7,
#             "wdir": 203,
#             "wdir_cardinal": "SSW",
#             "wspd": 27,
#             "wxman": "wx2050"
#         }
#     ],
#     "metadata": {
#         "expire_time_gmt": 1488969976,
#         "language": "en-US",
#         "location_id": "97229:4:US",
#         "status_code": 200,
#         "transaction_id": "1488969376659:1044592821",
#         "units": "m",
#         "version": "1"
#     }
# }

# %% [markdown]
# ### Getting a daily forecast
#
# You can issue a GET operation in your application to retrieve the 10-day forecast data. For example, you can use the following GET request to retrieve the 10-day forecast for Ottawa, ON, Canada:

# %%
print_api_resp("api/weather/v1/geocode/45.42/75.69/forecast/daily/10day.json?units=m&language=en-US",credentials_1)
# Out:
# {
#     "forecasts": [
#         {
#             "blurb": null,
#             "blurb_author": null,
#             "class": "fod_long_range_daily",
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1488934800,
#             "fcst_valid_local": "2017-03-08T07:00:00+0600",
#             "lunar_phase": "Waxing Gibbous",
#             "lunar_phase_code": "WXG",
#             "lunar_phase_day": 10,
#             "max_temp": null,
#             "min_temp": -6,
#             "moonrise": "2017-03-08T14:22:17+0600",
#             "moonset": "2017-03-08T04:33:57+0600",
#             "narrative": "Cloudy. Low -6C.",
#             "night": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Tonight",
#                 "clds": 75,
#                 "day_ind": "N",
#                 "daypart_name": "Tonight",
#                 "fcst_valid": 1488978000,
#                 "fcst_valid_local": "2017-03-08T19:00:00+0600",
#                 "golf_category": "",
#                 "golf_index": null,
#                 "hi": 2,
#                 "icon_code": 26,
#                 "icon_extd": 2600,
#                 "long_daypart_name": "Wednesday night",
#                 "narrative": "Cloudy skies. Low -6C. Winds light and variable.",
#                 "num": 1,
#                 "phrase_12char": "Cloudy",
#                 "phrase_22char": "Cloudy",
#                 "phrase_32char": "Cloudy",
#                 "pop": 10,
#                 "pop_phrase": "",
#                 "precip_type": "snow",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 94,
#                 "shortcast": "Cloudy",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Cloudy",
#                 "subphrase_pt2": "",
#                 "subphrase_pt3": "",
#                 "temp": -6,
#                 "temp_phrase": "Low -6C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Low",
#                 "uv_index": 0,
#                 "uv_index_raw": 0,
#                 "uv_warning": 0,
#                 "vocal_key": "D2:DA02:X2600260021:S260021:TL-6:W9902",
#                 "wc": -10,
#                 "wdir": 148,
#                 "wdir_cardinal": "SSE",
#                 "wind_phrase": "Winds light and variable.",
#                 "wspd": 9,
#                 "wxman": "wx1210"
#             },
#             "num": 1,
#             "qpf": 0.0,
#             "qualifier": null,
#             "qualifier_code": null,
#             "snow_code": "",
#             "snow_phrase": "",
#             "snow_qpf": 0.0,
#             "snow_range": "",
#             "stormcon": null,
#             "sunrise": "2017-03-08T07:23:23+0600",
#             "sunset": "2017-03-08T18:53:36+0600",
#             "torcon": null
#         },
#         {
#             "blurb": null,
#             "blurb_author": null,
#             "class": "fod_long_range_daily",
#             "day": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Thursday",
#                 "clds": 92,
#                 "day_ind": "D",
#                 "daypart_name": "Tomorrow",
#                 "fcst_valid": 1489021200,
#                 "fcst_valid_local": "2017-03-09T07:00:00+0600",
#                 "golf_category": "Fair",
#                 "golf_index": 4,
#                 "hi": 5,
#                 "icon_code": 26,
#                 "icon_extd": 2600,
#                 "long_daypart_name": "Thursday",
#                 "narrative": "Cloudy. High around 5C. Winds S at 10 to 15 km/h.",
#                 "num": 2,
#                 "phrase_12char": "Cloudy",
#                 "phrase_22char": "Cloudy",
#                 "phrase_32char": "Cloudy",
#                 "pop": 20,
#                 "pop_phrase": "",
#                 "precip_type": "rain",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 81,
#                 "shortcast": "Mostly cloudy",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Cloudy",
#                 "subphrase_pt2": "",
#                 "subphrase_pt3": "",
#                 "temp": 5,
#                 "temp_phrase": "High around 5C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Low",
#                 "uv_index": 1,
#                 "uv_index_raw": 1.36,
#                 "uv_warning": 0,
#                 "vocal_key": "D3:DA12:X2600260032:S260032:TH5:W08R02",
#                 "wc": -10,
#                 "wdir": 188,
#                 "wdir_cardinal": "S",
#                 "wind_phrase": "Winds S at 10 to 15 km/h.",
#                 "wspd": 15,
#                 "wxman": "wx1210"
#             },
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489021200,
#             "fcst_valid_local": "2017-03-09T07:00:00+0600",
#             "lunar_phase": "Waxing Gibbous",
#             "lunar_phase_code": "WXG",
#             "lunar_phase_day": 11,
#             "max_temp": 5,
#             "min_temp": -6,
#             "moonrise": "2017-03-09T15:27:33+0600",
#             "moonset": "2017-03-09T05:22:01+0600",
#             "narrative": "Mostly cloudy. Highs 4 to 6C and lows -7 to -5C.",
#             "night": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Thursday night",
#                 "clds": 65,
#                 "day_ind": "N",
#                 "daypart_name": "Tomorrow night",
#                 "fcst_valid": 1489064400,
#                 "fcst_valid_local": "2017-03-09T19:00:00+0600",
#                 "golf_category": "",
#                 "golf_index": null,
#                 "hi": 1,
#                 "icon_code": 29,
#                 "icon_extd": 2900,
#                 "long_daypart_name": "Thursday night",
#                 "narrative": "Partly cloudy skies during the evening will give way to cloudy skies overnight. Low -6C. Winds W at 10 to 15 km/h.",
#                 "num": 3,
#                 "phrase_12char": "P Cloudy",
#                 "phrase_22char": "Partly Cloudy",
#                 "phrase_32char": "Partly Cloudy",
#                 "pop": 20,
#                 "pop_phrase": "",
#                 "precip_type": "snow",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 99,
#                 "shortcast": "Partly cloudy",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Partly",
#                 "subphrase_pt2": "Cloudy",
#                 "subphrase_pt3": "",
#                 "temp": -6,
#                 "temp_phrase": "Low -6C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Low",
#                 "uv_index": 0,
#                 "uv_index_raw": 0,
#                 "uv_warning": 0,
#                 "vocal_key": "D4:DA13:X3000280044:S300042:TL-6:W12R02",
#                 "wc": -10,
#                 "wdir": 275,
#                 "wdir_cardinal": "W",
#                 "wind_phrase": "Winds W at 10 to 15 km/h.",
#                 "wspd": 13,
#                 "wxman": "wx1610"
#             },
#             "num": 2,
#             "qpf": 0.0,
#             "qualifier": null,
#             "qualifier_code": null,
#             "snow_code": "",
#             "snow_phrase": "",
#             "snow_qpf": 0.0,
#             "snow_range": "",
#             "stormcon": null,
#             "sunrise": "2017-03-09T07:21:32+0600",
#             "sunset": "2017-03-09T18:54:58+0600",
#             "torcon": null
#         },
#         {
#             "blurb": null,
#             "blurb_author": null,
#             "class": "fod_long_range_daily",
#             "day": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Friday",
#                 "clds": 69,
#                 "day_ind": "D",
#                 "daypart_name": "Friday",
#                 "fcst_valid": 1489107600,
#                 "fcst_valid_local": "2017-03-10T07:00:00+0600",
#                 "golf_category": "Very Poor",
#                 "golf_index": 2,
#                 "hi": 1,
#                 "icon_code": 28,
#                 "icon_extd": 2800,
#                 "long_daypart_name": "Friday",
#                 "narrative": "Mainly cloudy. High 2C. Winds WSW at 10 to 15 km/h.",
#                 "num": 4,
#                 "phrase_12char": "M Cloudy",
#                 "phrase_22char": "Mostly Cloudy",
#                 "phrase_32char": "Mostly Cloudy",
#                 "pop": 10,
#                 "pop_phrase": "",
#                 "precip_type": "precip",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 79,
#                 "shortcast": "Considerable cloudiness",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Mostly",
#                 "subphrase_pt2": "Cloudy",
#                 "subphrase_pt3": "",
#                 "temp": 2,
#                 "temp_phrase": "High 2C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Moderate",
#                 "uv_index": 3,
#                 "uv_index_raw": 2.52,
#                 "uv_warning": 0,
#                 "vocal_key": "D5:DA14:X2800280034:S280032:TH2:W11R02",
#                 "wc": -11,
#                 "wdir": 237,
#                 "wdir_cardinal": "WSW",
#                 "wind_phrase": "Winds WSW at 10 to 15 km/h.",
#                 "wspd": 16,
#                 "wxman": "wx1210"
#             },
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489107600,
#             "fcst_valid_local": "2017-03-10T07:00:00+0600",
#             "lunar_phase": "Waxing Gibbous",
#             "lunar_phase_code": "WXG",
#             "lunar_phase_day": 12,
#             "max_temp": 2,
#             "min_temp": -9,
#             "moonrise": "2017-03-10T16:33:34+0600",
#             "moonset": "2017-03-10T06:02:59+0600",
#             "narrative": "Mostly cloudy. Highs 1 to 3C and lows -10 to -8C.",
#             "night": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Friday night",
#                 "clds": 37,
#                 "day_ind": "N",
#                 "daypart_name": "Friday night",
#                 "fcst_valid": 1489150800,
#                 "fcst_valid_local": "2017-03-10T19:00:00+0600",
#                 "golf_category": "",
#                 "golf_index": null,
#                 "hi": -1,
#                 "icon_code": 29,
#                 "icon_extd": 2900,
#                 "long_daypart_name": "Friday night",
#                 "narrative": "Some clouds early will give way to generally clear conditions overnight. Low -9C. Winds WNW at 10 to 15 km/h.",
#                 "num": 5,
#                 "phrase_12char": "P Cloudy",
#                 "phrase_22char": "Partly Cloudy",
#                 "phrase_32char": "Partly Cloudy",
#                 "pop": 10,
#                 "pop_phrase": "",
#                 "precip_type": "snow",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 95,
#                 "shortcast": "Partly cloudy",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Partly",
#                 "subphrase_pt2": "Cloudy",
#                 "subphrase_pt3": "",
#                 "temp": -9,
#                 "temp_phrase": "Low -9C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Low",
#                 "uv_index": 0,
#                 "uv_index_raw": 0,
#                 "uv_warning": 0,
#                 "vocal_key": "D6:DA15:X3000320042:S300042:TL-9:W13R02",
#                 "wc": -13,
#                 "wdir": 298,
#                 "wdir_cardinal": "WNW",
#                 "wind_phrase": "Winds WNW at 10 to 15 km/h.",
#                 "wspd": 12,
#                 "wxman": "wx1610"
#             },
#             "num": 3,
#             "qpf": 0.0,
#             "qualifier": null,
#             "qualifier_code": null,
#             "snow_code": "",
#             "snow_phrase": "",
#             "snow_qpf": 0.0,
#             "snow_range": "",
#             "stormcon": null,
#             "sunrise": "2017-03-10T07:19:40+0600",
#             "sunset": "2017-03-10T18:56:19+0600",
#             "torcon": null
#         },
#         {
#             "blurb": null,
#             "blurb_author": null,
#             "class": "fod_long_range_daily",
#             "day": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Saturday",
#                 "clds": 35,
#                 "day_ind": "D",
#                 "daypart_name": "Saturday",
#                 "fcst_valid": 1489194000,
#                 "fcst_valid_local": "2017-03-11T07:00:00+0600",
#                 "golf_category": "Poor",
#                 "golf_index": 3,
#                 "hi": 3,
#                 "icon_code": 34,
#                 "icon_extd": 3400,
#                 "long_daypart_name": "Saturday",
#                 "narrative": "Mostly sunny skies. High 3C. Winds N at 15 to 25 km/h.",
#                 "num": 6,
#                 "phrase_12char": "M Sunny",
#                 "phrase_22char": "Mostly Sunny",
#                 "phrase_32char": "Mostly Sunny",
#                 "pop": 10,
#                 "pop_phrase": "",
#                 "precip_type": "precip",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 72,
#                 "shortcast": "Mostly sunny",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Mostly",
#                 "subphrase_pt2": "Sunny",
#                 "subphrase_pt3": "",
#                 "temp": 3,
#                 "temp_phrase": "High 3C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Moderate",
#                 "uv_index": 3,
#                 "uv_index_raw": 3.22,
#                 "uv_warning": 0,
#                 "vocal_key": "D7:DA16:X3400300032:S340032:TH3:W16R03",
#                 "wc": -13,
#                 "wdir": 3,
#                 "wdir_cardinal": "N",
#                 "wind_phrase": "Winds N at 15 to 25 km/h.",
#                 "wspd": 18,
#                 "wxman": "wx1010"
#             },
#             "dow": "Saturday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489194000,
#             "fcst_valid_local": "2017-03-11T07:00:00+0600",
#             "lunar_phase": "Waxing Gibbous",
#             "lunar_phase_code": "WXG",
#             "lunar_phase_day": 13,
#             "max_temp": 3,
#             "min_temp": -7,
#             "moonrise": "2017-03-11T17:40:33+0600",
#             "moonset": "2017-03-11T06:38:49+0600",
#             "narrative": "A few clouds. Highs 2 to 4C and lows -8 to -6C.",
#             "night": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Saturday night",
#                 "clds": 71,
#                 "day_ind": "N",
#                 "daypart_name": "Saturday night",
#                 "fcst_valid": 1489237200,
#                 "fcst_valid_local": "2017-03-11T19:00:00+0600",
#                 "golf_category": "",
#                 "golf_index": null,
#                 "hi": 0,
#                 "icon_code": 27,
#                 "icon_extd": 2700,
#                 "long_daypart_name": "Saturday night",
#                 "narrative": "Mainly cloudy. Low -7C. Winds N at 10 to 15 km/h.",
#                 "num": 7,
#                 "phrase_12char": "M Cloudy",
#                 "phrase_22char": "Mostly Cloudy",
#                 "phrase_32char": "Mostly Cloudy",
#                 "pop": 20,
#                 "pop_phrase": "",
#                 "precip_type": "snow",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 94,
#                 "shortcast": "Mostly cloudy",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Mostly",
#                 "subphrase_pt2": "Cloudy",
#                 "subphrase_pt3": "",
#                 "temp": -7,
#                 "temp_phrase": "Low -7C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Low",
#                 "uv_index": 0,
#                 "uv_index_raw": 0,
#                 "uv_warning": 0,
#                 "vocal_key": "D8:DA17:X2800280044:S280041:TL-7:W16R02",
#                 "wc": -11,
#                 "wdir": 2,
#                 "wdir_cardinal": "N",
#                 "wind_phrase": "Winds N at 10 to 15 km/h.",
#                 "wspd": 16,
#                 "wxman": "wx1210"
#             },
#             "num": 4,
#             "qpf": 0.0,
#             "qualifier": null,
#             "qualifier_code": null,
#             "snow_code": "",
#             "snow_phrase": "",
#             "snow_qpf": 0.0,
#             "snow_range": "",
#             "stormcon": null,
#             "sunrise": "2017-03-11T07:17:48+0600",
#             "sunset": "2017-03-11T18:57:41+0600",
#             "torcon": null
#         },
#         {
#             "blurb": null,
#             "blurb_author": null,
#             "class": "fod_long_range_daily",
#             "day": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Sunday",
#                 "clds": 44,
#                 "day_ind": "D",
#                 "daypart_name": "Sunday",
#                 "fcst_valid": 1489280400,
#                 "fcst_valid_local": "2017-03-12T07:00:00+0600",
#                 "golf_category": "Poor",
#                 "golf_index": 3,
#                 "hi": 2,
#                 "icon_code": 30,
#                 "icon_extd": 3000,
#                 "long_daypart_name": "Sunday",
#                 "narrative": "Sunshine and clouds mixed. High 3C. Winds NNE at 10 to 15 km/h.",
#                 "num": 8,
#                 "phrase_12char": "P Cloudy",
#                 "phrase_22char": "Partly Cloudy",
#                 "phrase_32char": "Partly Cloudy",
#                 "pop": 10,
#                 "pop_phrase": "",
#                 "precip_type": "precip",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 78,
#                 "shortcast": "Partly cloudy",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Partly",
#                 "subphrase_pt2": "Cloudy",
#                 "subphrase_pt3": "",
#                 "temp": 3,
#                 "temp_phrase": "High 3C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Moderate",
#                 "uv_index": 3,
#                 "uv_index_raw": 3.28,
#                 "uv_warning": 0,
#                 "vocal_key": "D9:DA04:X3000300034:S300031:TH3:W01R02",
#                 "wc": -11,
#                 "wdir": 29,
#                 "wdir_cardinal": "NNE",
#                 "wind_phrase": "Winds NNE at 10 to 15 km/h.",
#                 "wspd": 15,
#                 "wxman": "wx1110"
#             },
#             "dow": "Sunday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489280400,
#             "fcst_valid_local": "2017-03-12T07:00:00+0600",
#             "lunar_phase": "Full Moon",
#             "lunar_phase_code": "F",
#             "lunar_phase_day": 14,
#             "max_temp": 3,
#             "min_temp": -8,
#             "moonrise": "2017-03-12T18:45:43+0600",
#             "moonset": "2017-03-12T07:11:09+0600",
#             "narrative": "Mix of sun and clouds. Highs 2 to 4C and lows -9 to -7C.",
#             "night": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Sunday night",
#                 "clds": 58,
#                 "day_ind": "N",
#                 "daypart_name": "Sunday night",
#                 "fcst_valid": 1489323600,
#                 "fcst_valid_local": "2017-03-12T19:00:00+0600",
#                 "golf_category": "",
#                 "golf_index": null,
#                 "hi": 0,
#                 "icon_code": 29,
#                 "icon_extd": 2900,
#                 "long_daypart_name": "Sunday night",
#                 "narrative": "Mostly cloudy skies early will become partly cloudy late. Low -8C. Winds NE at 10 to 15 km/h.",
#                 "num": 9,
#                 "phrase_12char": "P Cloudy",
#                 "phrase_22char": "Partly Cloudy",
#                 "phrase_32char": "Partly Cloudy",
#                 "pop": 10,
#                 "pop_phrase": "",
#                 "precip_type": "snow",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 95,
#                 "shortcast": "Partly cloudy",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Partly",
#                 "subphrase_pt2": "Cloudy",
#                 "subphrase_pt3": "",
#                 "temp": -8,
#                 "temp_phrase": "Low -8C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Low",
#                 "uv_index": 0,
#                 "uv_index_raw": 0,
#                 "uv_warning": 0,
#                 "vocal_key": "D10:DA05:X2800300041:S300041:TL-8:W02R02",
#                 "wc": -12,
#                 "wdir": 40,
#                 "wdir_cardinal": "NE",
#                 "wind_phrase": "Winds NE at 10 to 15 km/h.",
#                 "wspd": 14,
#                 "wxman": "wx1610"
#             },
#             "num": 5,
#             "qpf": 0.0,
#             "qualifier": null,
#             "qualifier_code": null,
#             "snow_code": "",
#             "snow_phrase": "",
#             "snow_qpf": 0.0,
#             "snow_range": "",
#             "stormcon": null,
#             "sunrise": "2017-03-12T07:15:55+0600",
#             "sunset": "2017-03-12T18:59:02+0600",
#             "torcon": null
#         },
#         {
#             "blurb": null,
#             "blurb_author": null,
#             "class": "fod_long_range_daily",
#             "day": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Monday",
#                 "clds": 25,
#                 "day_ind": "D",
#                 "daypart_name": "Monday",
#                 "fcst_valid": 1489366800,
#                 "fcst_valid_local": "2017-03-13T07:00:00+0600",
#                 "golf_category": "Fair",
#                 "golf_index": 4,
#                 "hi": 4,
#                 "icon_code": 34,
#                 "icon_extd": 3400,
#                 "long_daypart_name": "Monday",
#                 "narrative": "A few clouds early, otherwise mostly sunny. High around 5C. Winds NE at 15 to 25 km/h.",
#                 "num": 10,
#                 "phrase_12char": "M Sunny",
#                 "phrase_22char": "Mostly Sunny",
#                 "phrase_32char": "Mostly Sunny",
#                 "pop": 10,
#                 "pop_phrase": "",
#                 "precip_type": "rain",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 74,
#                 "shortcast": "Mostly sunny",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Mostly",
#                 "subphrase_pt2": "Sunny",
#                 "subphrase_pt3": "",
#                 "temp": 5,
#                 "temp_phrase": "High around 5C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Moderate",
#                 "uv_index": 3,
#                 "uv_index_raw": 3.34,
#                 "uv_warning": 0,
#                 "vocal_key": "D11:DA06:X3000340032:S340032:TH5:W02R03",
#                 "wc": -13,
#                 "wdir": 47,
#                 "wdir_cardinal": "NE",
#                 "wind_phrase": "Winds NE at 15 to 25 km/h.",
#                 "wspd": 18,
#                 "wxman": "wx1010"
#             },
#             "dow": "Monday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489366800,
#             "fcst_valid_local": "2017-03-13T07:00:00+0600",
#             "lunar_phase": "Full Moon",
#             "lunar_phase_code": "F",
#             "lunar_phase_day": 15,
#             "max_temp": 5,
#             "min_temp": -7,
#             "moonrise": "2017-03-13T19:50:09+0600",
#             "moonset": "2017-03-13T07:40:41+0600",
#             "narrative": "Plenty of sun. Highs 4 to 6C and lows -8 to -6C.",
#             "night": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Monday night",
#                 "clds": 18,
#                 "day_ind": "N",
#                 "daypart_name": "Monday night",
#                 "fcst_valid": 1489410000,
#                 "fcst_valid_local": "2017-03-13T19:00:00+0600",
#                 "golf_category": "",
#                 "golf_index": null,
#                 "hi": 1,
#                 "icon_code": 33,
#                 "icon_extd": 3300,
#                 "long_daypart_name": "Monday night",
#                 "narrative": "A mostly clear sky. Low -7C. Winds NE at 10 to 15 km/h.",
#                 "num": 11,
#                 "phrase_12char": "M Clear",
#                 "phrase_22char": "Mostly Clear",
#                 "phrase_32char": "Mostly Clear",
#                 "pop": 10,
#                 "pop_phrase": "",
#                 "precip_type": "snow",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 90,
#                 "shortcast": "Mostly clear",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Mostly",
#                 "subphrase_pt2": "Clear",
#                 "subphrase_pt3": "",
#                 "temp": -7,
#                 "temp_phrase": "Low -7C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Low",
#                 "uv_index": 0,
#                 "uv_index_raw": 0,
#                 "uv_warning": 0,
#                 "vocal_key": "D12:DA07:X3200340044:S340042:TL-7:W02R02",
#                 "wc": -12,
#                 "wdir": 34,
#                 "wdir_cardinal": "NE",
#                 "wind_phrase": "Winds NE at 10 to 15 km/h.",
#                 "wspd": 16,
#                 "wxman": "wx1510"
#             },
#             "num": 6,
#             "qpf": 0.0,
#             "qualifier": null,
#             "qualifier_code": null,
#             "snow_code": "",
#             "snow_phrase": "",
#             "snow_qpf": 0.0,
#             "snow_range": "",
#             "stormcon": null,
#             "sunrise": "2017-03-13T07:14:02+0600",
#             "sunset": "2017-03-13T19:00:23+0600",
#             "torcon": null
#         },
#         {
#             "blurb": null,
#             "blurb_author": null,
#             "class": "fod_long_range_daily",
#             "day": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Tuesday",
#                 "clds": 39,
#                 "day_ind": "D",
#                 "daypart_name": "Tuesday",
#                 "fcst_valid": 1489453200,
#                 "fcst_valid_local": "2017-03-14T07:00:00+0600",
#                 "golf_category": "Fair",
#                 "golf_index": 4,
#                 "hi": 4,
#                 "icon_code": 30,
#                 "icon_extd": 3000,
#                 "long_daypart_name": "Tuesday",
#                 "narrative": "Intervals of clouds and sunshine. High around 5C. Winds NNE at 10 to 15 km/h.",
#                 "num": 12,
#                 "phrase_12char": "P Cloudy",
#                 "phrase_22char": "Partly Cloudy",
#                 "phrase_32char": "Partly Cloudy",
#                 "pop": 10,
#                 "pop_phrase": "",
#                 "precip_type": "rain",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 76,
#                 "shortcast": "Times of sun and clouds",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Partly",
#                 "subphrase_pt2": "Cloudy",
#                 "subphrase_pt3": "",
#                 "temp": 5,
#                 "temp_phrase": "High around 5C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Moderate",
#                 "uv_index": 3,
#                 "uv_index_raw": 3.4,
#                 "uv_warning": 0,
#                 "vocal_key": "D13:DA08:X3000300031:S300033:TH5:W01R02",
#                 "wc": -12,
#                 "wdir": 18,
#                 "wdir_cardinal": "NNE",
#                 "wind_phrase": "Winds NNE at 10 to 15 km/h.",
#                 "wspd": 14,
#                 "wxman": "wx1110"
#             },
#             "dow": "Tuesday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489453200,
#             "fcst_valid_local": "2017-03-14T07:00:00+0600",
#             "lunar_phase": "Waning Gibbous",
#             "lunar_phase_code": "WNG",
#             "lunar_phase_day": 16,
#             "max_temp": 5,
#             "min_temp": -7,
#             "moonrise": "2017-03-14T20:52:36+0600",
#             "moonset": "2017-03-14T08:08:17+0600",
#             "narrative": "Times of sun and clouds. Highs 4 to 6C and lows -8 to -6C.",
#             "night": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Tuesday night",
#                 "clds": 45,
#                 "day_ind": "N",
#                 "daypart_name": "Tuesday night",
#                 "fcst_valid": 1489496400,
#                 "fcst_valid_local": "2017-03-14T19:00:00+0600",
#                 "golf_category": "",
#                 "golf_index": null,
#                 "hi": 2,
#                 "icon_code": 29,
#                 "icon_extd": 2900,
#                 "long_daypart_name": "Tuesday night",
#                 "narrative": "A few clouds. Low -7C. Winds NW at 10 to 15 km/h.",
#                 "num": 13,
#                 "phrase_12char": "P Cloudy",
#                 "phrase_22char": "Partly Cloudy",
#                 "phrase_32char": "Partly Cloudy",
#                 "pop": 10,
#                 "pop_phrase": "",
#                 "precip_type": "snow",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 94,
#                 "shortcast": "Partly cloudy",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Partly",
#                 "subphrase_pt2": "Cloudy",
#                 "subphrase_pt3": "",
#                 "temp": -7,
#                 "temp_phrase": "Low -7C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Low",
#                 "uv_index": 0,
#                 "uv_index_raw": 0,
#                 "uv_warning": 0,
#                 "vocal_key": "D14:DA09:X3000300044:S300043:TL-7:W14R02",
#                 "wc": -10,
#                 "wdir": 317,
#                 "wdir_cardinal": "NW",
#                 "wind_phrase": "Winds NW at 10 to 15 km/h.",
#                 "wspd": 12,
#                 "wxman": "wx1610"
#             },
#             "num": 7,
#             "qpf": 0.0,
#             "qualifier": null,
#             "qualifier_code": null,
#             "snow_code": "",
#             "snow_phrase": "",
#             "snow_qpf": 0.0,
#             "snow_range": "",
#             "stormcon": null,
#             "sunrise": "2017-03-14T07:12:08+0600",
#             "sunset": "2017-03-14T19:01:43+0600",
#             "torcon": null
#         },
#         {
#             "blurb": null,
#             "blurb_author": null,
#             "class": "fod_long_range_daily",
#             "day": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Wednesday",
#                 "clds": 50,
#                 "day_ind": "D",
#                 "daypart_name": "Wednesday",
#                 "fcst_valid": 1489539600,
#                 "fcst_valid_local": "2017-03-15T07:00:00+0600",
#                 "golf_category": "Fair",
#                 "golf_index": 4,
#                 "hi": 4,
#                 "icon_code": 30,
#                 "icon_extd": 3000,
#                 "long_daypart_name": "Wednesday",
#                 "narrative": "Partly cloudy. High near 5C. Winds WNW at 10 to 15 km/h.",
#                 "num": 14,
#                 "phrase_12char": "P Cloudy",
#                 "phrase_22char": "Partly Cloudy",
#                 "phrase_32char": "Partly Cloudy",
#                 "pop": 10,
#                 "pop_phrase": "",
#                 "precip_type": "rain",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 78,
#                 "shortcast": "Partly cloudy",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Partly",
#                 "subphrase_pt2": "Cloudy",
#                 "subphrase_pt3": "",
#                 "temp": 5,
#                 "temp_phrase": "High near 5C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Moderate",
#                 "uv_index": 3,
#                 "uv_index_raw": 3.47,
#                 "uv_warning": 0,
#                 "vocal_key": "D15:DA10:X3000300033:S300031:TH5:W13R02",
#                 "wc": -11,
#                 "wdir": 290,
#                 "wdir_cardinal": "WNW",
#                 "wind_phrase": "Winds WNW at 10 to 15 km/h.",
#                 "wspd": 13,
#                 "wxman": "wx1110"
#             },
#             "dow": "Wednesday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489539600,
#             "fcst_valid_local": "2017-03-15T07:00:00+0600",
#             "lunar_phase": "Waning Gibbous",
#             "lunar_phase_code": "WNG",
#             "lunar_phase_day": 17,
#             "max_temp": 5,
#             "min_temp": -7,
#             "moonrise": "2017-03-15T21:54:07+0600",
#             "moonset": "2017-03-15T08:35:51+0600",
#             "narrative": "Mix of sun and clouds. Highs 4 to 6C and lows -8 to -6C.",
#             "night": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Wednesday night",
#                 "clds": 43,
#                 "day_ind": "N",
#                 "daypart_name": "Wednesday night",
#                 "fcst_valid": 1489582800,
#                 "fcst_valid_local": "2017-03-15T19:00:00+0600",
#                 "golf_category": "",
#                 "golf_index": null,
#                 "hi": 1,
#                 "icon_code": 29,
#                 "icon_extd": 2900,
#                 "long_daypart_name": "Wednesday night",
#                 "narrative": "Partly cloudy skies. Low -7C. Winds N at 10 to 15 km/h.",
#                 "num": 15,
#                 "phrase_12char": "P Cloudy",
#                 "phrase_22char": "Partly Cloudy",
#                 "phrase_32char": "Partly Cloudy",
#                 "pop": 10,
#                 "pop_phrase": "",
#                 "precip_type": "snow",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 92,
#                 "shortcast": "Partly cloudy",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Partly",
#                 "subphrase_pt2": "Cloudy",
#                 "subphrase_pt3": "",
#                 "temp": -7,
#                 "temp_phrase": "Low -7C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Low",
#                 "uv_index": 0,
#                 "uv_index_raw": 0,
#                 "uv_warning": 0,
#                 "vocal_key": "D16:DA11:X3000300041:S300042:TL-7:W16R02",
#                 "wc": -11,
#                 "wdir": 7,
#                 "wdir_cardinal": "N",
#                 "wind_phrase": "Winds N at 10 to 15 km/h.",
#                 "wspd": 13,
#                 "wxman": "wx1610"
#             },
#             "num": 8,
#             "qpf": 0.0,
#             "qualifier": null,
#             "qualifier_code": null,
#             "snow_code": "",
#             "snow_phrase": "",
#             "snow_qpf": 0.0,
#             "snow_range": "",
#             "stormcon": null,
#             "sunrise": "2017-03-15T07:10:14+0600",
#             "sunset": "2017-03-15T19:03:04+0600",
#             "torcon": null
#         },
#         {
#             "blurb": null,
#             "blurb_author": null,
#             "class": "fod_long_range_daily",
#             "day": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Thursday",
#                 "clds": 42,
#                 "day_ind": "D",
#                 "daypart_name": "Thursday",
#                 "fcst_valid": 1489626000,
#                 "fcst_valid_local": "2017-03-16T07:00:00+0600",
#                 "golf_category": "Poor",
#                 "golf_index": 3,
#                 "hi": 3,
#                 "icon_code": 30,
#                 "icon_extd": 3000,
#                 "long_daypart_name": "Thursday",
#                 "narrative": "Partly cloudy. High 3C. Winds NNE at 10 to 15 km/h.",
#                 "num": 16,
#                 "phrase_12char": "P Cloudy",
#                 "phrase_22char": "Partly Cloudy",
#                 "phrase_32char": "Partly Cloudy",
#                 "pop": 10,
#                 "pop_phrase": "",
#                 "precip_type": "precip",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 76,
#                 "shortcast": "Mix of sun and clouds",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Partly",
#                 "subphrase_pt2": "Cloudy",
#                 "subphrase_pt3": "",
#                 "temp": 3,
#                 "temp_phrase": "High 3C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Moderate",
#                 "uv_index": 4,
#                 "uv_index_raw": 3.53,
#                 "uv_warning": 0,
#                 "vocal_key": "D17:DA12:X3000300033:S300032:TH3:W01R02",
#                 "wc": -11,
#                 "wdir": 28,
#                 "wdir_cardinal": "NNE",
#                 "wind_phrase": "Winds NNE at 10 to 15 km/h.",
#                 "wspd": 16,
#                 "wxman": "wx1110"
#             },
#             "dow": "Thursday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489626000,
#             "fcst_valid_local": "2017-03-16T07:00:00+0600",
#             "lunar_phase": "Waning Gibbous",
#             "lunar_phase_code": "WNG",
#             "lunar_phase_day": 18,
#             "max_temp": 3,
#             "min_temp": -8,
#             "moonrise": "2017-03-16T22:54:00+0600",
#             "moonset": "2017-03-16T09:04:25+0600",
#             "narrative": "Mix of sun and clouds. Highs 2 to 4C and lows -9 to -7C.",
#             "night": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Thursday night",
#                 "clds": 14,
#                 "day_ind": "N",
#                 "daypart_name": "Thursday night",
#                 "fcst_valid": 1489669200,
#                 "fcst_valid_local": "2017-03-16T19:00:00+0600",
#                 "golf_category": "",
#                 "golf_index": null,
#                 "hi": 0,
#                 "icon_code": 33,
#                 "icon_extd": 3300,
#                 "long_daypart_name": "Thursday night",
#                 "narrative": "A mostly clear sky. Low -8C. Winds NE at 10 to 15 km/h.",
#                 "num": 17,
#                 "phrase_12char": "M Clear",
#                 "phrase_22char": "Mostly Clear",
#                 "phrase_32char": "Mostly Clear",
#                 "pop": 10,
#                 "pop_phrase": "",
#                 "precip_type": "snow",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 88,
#                 "shortcast": "Mostly clear",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Mostly",
#                 "subphrase_pt2": "Clear",
#                 "subphrase_pt3": "",
#                 "temp": -8,
#                 "temp_phrase": "Low -8C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Low",
#                 "uv_index": 0,
#                 "uv_index_raw": 0,
#                 "uv_warning": 0,
#                 "vocal_key": "D18:DA13:X3400320043:S340042:TL-8:W02R02",
#                 "wc": -13,
#                 "wdir": 44,
#                 "wdir_cardinal": "NE",
#                 "wind_phrase": "Winds NE at 10 to 15 km/h.",
#                 "wspd": 15,
#                 "wxman": "wx1510"
#             },
#             "num": 9,
#             "qpf": 0.0,
#             "qualifier": null,
#             "qualifier_code": null,
#             "snow_code": "",
#             "snow_phrase": "",
#             "snow_qpf": 0.0,
#             "snow_range": "",
#             "stormcon": null,
#             "sunrise": "2017-03-16T07:08:20+0600",
#             "sunset": "2017-03-16T19:04:24+0600",
#             "torcon": null
#         },
#         {
#             "blurb": null,
#             "blurb_author": null,
#             "class": "fod_long_range_daily",
#             "day": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Friday",
#                 "clds": 8,
#                 "day_ind": "D",
#                 "daypart_name": "Friday",
#                 "fcst_valid": 1489712400,
#                 "fcst_valid_local": "2017-03-17T07:00:00+0600",
#                 "golf_category": "Poor",
#                 "golf_index": 3,
#                 "hi": 3,
#                 "icon_code": 32,
#                 "icon_extd": 3200,
#                 "long_daypart_name": "Friday",
#                 "narrative": "A mainly sunny sky. High 4C. Winds NE at 10 to 15 km/h.",
#                 "num": 18,
#                 "phrase_12char": "Sunny",
#                 "phrase_22char": "Sunny",
#                 "phrase_32char": "Sunny",
#                 "pop": 10,
#                 "pop_phrase": "",
#                 "precip_type": "precip",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 69,
#                 "shortcast": "Abundant sunshine",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Sunny",
#                 "subphrase_pt2": "",
#                 "subphrase_pt3": "",
#                 "temp": 4,
#                 "temp_phrase": "High 4C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Moderate",
#                 "uv_index": 4,
#                 "uv_index_raw": 3.6,
#                 "uv_warning": 0,
#                 "vocal_key": "D19:DA14:X3200320033:S320033:TH4:W02R02",
#                 "wc": -12,
#                 "wdir": 37,
#                 "wdir_cardinal": "NE",
#                 "wind_phrase": "Winds NE at 10 to 15 km/h.",
#                 "wspd": 15,
#                 "wxman": "wx1010"
#             },
#             "dow": "Friday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489712400,
#             "fcst_valid_local": "2017-03-17T07:00:00+0600",
#             "lunar_phase": "Waning Gibbous",
#             "lunar_phase_code": "WNG",
#             "lunar_phase_day": 19,
#             "max_temp": 4,
#             "min_temp": -7,
#             "moonrise": "2017-03-17T23:52:52+0600",
#             "moonset": "2017-03-17T09:34:37+0600",
#             "narrative": "Abundant sunshine. Highs 3 to 5C and lows -8 to -6C.",
#             "night": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Friday night",
#                 "clds": 12,
#                 "day_ind": "N",
#                 "daypart_name": "Friday night",
#                 "fcst_valid": 1489755600,
#                 "fcst_valid_local": "2017-03-17T19:00:00+0600",
#                 "golf_category": "",
#                 "golf_index": null,
#                 "hi": 0,
#                 "icon_code": 31,
#                 "icon_extd": 3100,
#                 "long_daypart_name": "Friday night",
#                 "narrative": "Clear skies. Low -7C. Winds NE at 10 to 15 km/h.",
#                 "num": 19,
#                 "phrase_12char": "Clear",
#                 "phrase_22char": "Clear",
#                 "phrase_32char": "Clear",
#                 "pop": 10,
#                 "pop_phrase": "",
#                 "precip_type": "snow",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 76,
#                 "shortcast": "Clear",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Clear",
#                 "subphrase_pt2": "",
#                 "subphrase_pt3": "",
#                 "temp": -7,
#                 "temp_phrase": "Low -7C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Low",
#                 "uv_index": 0,
#                 "uv_index_raw": 0,
#                 "uv_warning": 0,
#                 "vocal_key": "D20:DA15:X3200320044:S320043:TL-7:W02R02",
#                 "wc": -12,
#                 "wdir": 47,
#                 "wdir_cardinal": "NE",
#                 "wind_phrase": "Winds NE at 10 to 15 km/h.",
#                 "wspd": 15,
#                 "wxman": "wx1510"
#             },
#             "num": 10,
#             "qpf": 0.0,
#             "qualifier": null,
#             "qualifier_code": null,
#             "snow_code": "",
#             "snow_phrase": "",
#             "snow_qpf": 0.0,
#             "snow_range": "",
#             "stormcon": null,
#             "sunrise": "2017-03-17T07:06:25+0600",
#             "sunset": "2017-03-17T19:05:44+0600",
#             "torcon": null
#         },
#         {
#             "blurb": null,
#             "blurb_author": null,
#             "class": "fod_long_range_daily",
#             "day": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Saturday",
#                 "clds": 26,
#                 "day_ind": "D",
#                 "daypart_name": "Saturday",
#                 "fcst_valid": 1489798800,
#                 "fcst_valid_local": "2017-03-18T07:00:00+0600",
#                 "golf_category": "Fair",
#                 "golf_index": 4,
#                 "hi": 4,
#                 "icon_code": 34,
#                 "icon_extd": 3400,
#                 "long_daypart_name": "Saturday",
#                 "narrative": "Sunshine along with some cloudy intervals. High near 5C. Winds NE at 15 to 25 km/h.",
#                 "num": 20,
#                 "phrase_12char": "M Sunny",
#                 "phrase_22char": "Mostly Sunny",
#                 "phrase_32char": "Mostly Sunny",
#                 "pop": 0,
#                 "pop_phrase": "",
#                 "precip_type": "rain",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 54,
#                 "shortcast": "More sun than clouds",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Mostly",
#                 "subphrase_pt2": "Sunny",
#                 "subphrase_pt3": "",
#                 "temp": 5,
#                 "temp_phrase": "High near 5C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Moderate",
#                 "uv_index": 4,
#                 "uv_index_raw": 3.66,
#                 "uv_warning": 0,
#                 "vocal_key": "D21:DA16:X3000340031:S340034:TH5:W02R03",
#                 "wc": -12,
#                 "wdir": 47,
#                 "wdir_cardinal": "NE",
#                 "wind_phrase": "Winds NE at 15 to 25 km/h.",
#                 "wspd": 18,
#                 "wxman": "wx1010"
#             },
#             "dow": "Saturday",
#             "expire_time_gmt": 1488970670,
#             "fcst_valid": 1489798800,
#             "fcst_valid_local": "2017-03-18T07:00:00+0600",
#             "lunar_phase": "Waning Gibbous",
#             "lunar_phase_code": "WNG",
#             "lunar_phase_day": 20,
#             "max_temp": 5,
#             "min_temp": -6,
#             "moonrise": "",
#             "moonset": "2017-03-18T10:06:55+0600",
#             "narrative": "Mostly sunny. Highs 4 to 6C and lows -7 to -5C.",
#             "night": {
#                 "accumulation_phrase": "",
#                 "alt_daypart_name": "Saturday night",
#                 "clds": 17,
#                 "day_ind": "N",
#                 "daypart_name": "Saturday night",
#                 "fcst_valid": 1489842000,
#                 "fcst_valid_local": "2017-03-18T19:00:00+0600",
#                 "golf_category": "",
#                 "golf_index": null,
#                 "hi": 2,
#                 "icon_code": 31,
#                 "icon_extd": 3100,
#                 "long_daypart_name": "Saturday night",
#                 "narrative": "Clear skies. Low -6C. Winds NE at 15 to 25 km/h.",
#                 "num": 21,
#                 "phrase_12char": "Clear",
#                 "phrase_22char": "Clear",
#                 "phrase_32char": "Clear",
#                 "pop": 0,
#                 "pop_phrase": "",
#                 "precip_type": "snow",
#                 "qpf": 0.0,
#                 "qualifier": null,
#                 "qualifier_code": null,
#                 "rh": 63,
#                 "shortcast": "Clear",
#                 "snow_code": "",
#                 "snow_phrase": "",
#                 "snow_qpf": 0.0,
#                 "snow_range": "",
#                 "subphrase_pt1": "Clear",
#                 "subphrase_pt2": "",
#                 "subphrase_pt3": "",
#                 "temp": -6,
#                 "temp_phrase": "Low -6C.",
#                 "thunder_enum": 0,
#                 "thunder_enum_phrase": "No thunder",
#                 "uv_desc": "Low",
#                 "uv_index": 0,
#                 "uv_index_raw": 0,
#                 "uv_warning": 0,
#                 "vocal_key": "D22:DA17:X3200320041:S320042:TL-6:W02R03",
#                 "wc": -11,
#                 "wdir": 54,
#                 "wdir_cardinal": "NE",
#                 "wind_phrase": "Winds NE at 15 to 25 km/h.",
#                 "wspd": 17,
#                 "wxman": "wx1510"
#             },
#             "num": 11,
#             "qpf": 0.0,
#             "qualifier": null,
#             "qualifier_code": null,
#             "snow_code": "",
#             "snow_phrase": "",
#             "snow_qpf": 0.0,
#             "snow_range": "",
#             "stormcon": null,
#             "sunrise": "2017-03-18T07:04:31+0600",
#             "sunset": "2017-03-18T19:07:04+0600",
#             "torcon": null
#         }
#     ],
#     "metadata": {
#         "expire_time_gmt": 1488970670,
#         "language": "en-US",
#         "latitude": 45.42,
#         "longitude": 75.69,
#         "status_code": 200,
#         "transaction_id": "1488969452441:-1127225187",
#         "units": "m",
#         "version": "1"
#     }
# }

# %% [markdown]
# ### Getting current conditions
#
# You can issue a GET operation in your application to retrieve the current weather conditions. For example, you can use the following GET request to retrieve the current conditions for Ottawa, ON, Canada:

# %%
print_api_resp("api/weather/v1/geocode/45.42/75.69/observations.json?units=m&language=en-US",credentials_1)
# Out:
# {
#     "metadata": {
#         "expire_time_gmt": 1488975300,
#         "language": "en-US",
#         "latitude": 45.42,
#         "longitude": 75.69,
#         "status_code": 200,
#         "transaction_id": "1488969488284:-437251961",
#         "units": "m",
#         "version": "1"
#     },
#     "observation": {
#         "blunt_phrase": null,
#         "class": "observation",
#         "clds": 0,
#         "day_ind": "D",
#         "dewPt": -1,
#         "expire_time_gmt": 1488975300,
#         "feels_like": 6,
#         "gust": null,
#         "heat_index": 6,
#         "icon_extd": 3400,
#         "key": "36821",
#         "max_temp": null,
#         "min_temp": null,
#         "obs_id": "36821",
#         "obs_name": "Bakanas",
#         "precip_hrly": null,
#         "precip_total": null,
#         "pressure": 975.7,
#         "pressure_desc": "Falling",
#         "pressure_tend": 2,
#         "primary_swell_direction": null,
#         "primary_swell_height": null,
#         "primary_swell_period": null,
#         "primary_wave_height": null,
#         "primary_wave_period": null,
#         "qualifier": null,
#         "qualifier_svrty": null,
#         "rh": 61,
#         "secondary_swell_direction": null,
#         "secondary_swell_height": null,
#         "secondary_swell_period": null,
#         "snow_hrly": null,
#         "temp": 6,
#         "terse_phrase": null,
#         "uv_desc": "Low",
#         "uv_index": 2,
#         "valid_time_gmt": 1488963600,
#         "vis": 50,
#         "water_temp": null,
#         "wc": 6,
#         "wdir": 360,
#         "wdir_cardinal": "N",
#         "wspd": 4,
#         "wx_icon": 34,
#         "wx_phrase": "Fair"
#     }
# }

# %% [markdown]
# ### Getting alerts
# You can issue a GET operation in your application to retrieve the current weather alert headlines. For example, you can use the following GET request to retrieve the weather alert headlines for San Bernadino, CA, USA:

# %%
print_api_resp("api/weather/v1/geocode/34.12/-117.30/alerts.json?language=en-US",credentials_1)
# Out:
# {
#     "errors": [
#         {
#             "error": {
#                 "code": "NDF-0001",
#                 "message": "There was no data found for your alerts query."
#             }
#         }
#     ],
#     "metadata": {
#         "status_code": 400,
#         "transaction_id": "1488969540682:-712150715"
#     },
#     "success": false
# }

# %% [markdown]
# ### Getting almanac data
#
# You can issue a GET operation in your application to retrieve daily or monthly almanac data. For example, you can use the following GET request to retrieve the daily almanac information for Atlanta, GA, USA:

# %%
print_api_resp("api/weather/v1/geocode/33.40/-83.42/almanac/daily.json?units=e&start=0112&end=0115",credentials_1)
# Out:
# {
#     "almanac_summaries": [
#         {
#             "almanac_dt": "0112",
#             "avg_hi": 56.0,
#             "avg_lo": 28.0,
#             "avg_precip": 0.13,
#             "avg_snow": 0.1,
#             "class": "almanac",
#             "interval": "D",
#             "mean_temp": 42.0,
#             "record_hi": 71.0,
#             "record_hi_yr": 1974,
#             "record_lo": 0.0,
#             "record_lo_yr": 1982,
#             "record_period": 30,
#             "station_id": "095988",
#             "station_name": "MONTICELLO"
#         },
#         {
#             "almanac_dt": "0113",
#             "avg_hi": 56.0,
#             "avg_lo": 28.0,
#             "avg_precip": 0.12,
#             "avg_snow": 0.0,
#             "class": "almanac",
#             "interval": "D",
#             "mean_temp": 42.0,
#             "record_hi": 72.0,
#             "record_hi_yr": 1972,
#             "record_lo": 13.0,
#             "record_lo_yr": 1981,
#             "record_period": 30,
#             "station_id": "095988",
#             "station_name": "MONTICELLO"
#         },
#         {
#             "almanac_dt": "0114",
#             "avg_hi": 56.0,
#             "avg_lo": 28.0,
#             "avg_precip": 0.13,
#             "avg_snow": 0.0,
#             "class": "almanac",
#             "interval": "D",
#             "mean_temp": 42.0,
#             "record_hi": 71.0,
#             "record_hi_yr": 2000,
#             "record_lo": 14.0,
#             "record_lo_yr": 1956,
#             "record_period": 30,
#             "station_id": "095988",
#             "station_name": "MONTICELLO"
#         },
#         {
#             "almanac_dt": "0115",
#             "avg_hi": 56.0,
#             "avg_lo": 28.0,
#             "avg_precip": 0.12,
#             "avg_snow": 0.0,
#             "class": "almanac",
#             "interval": "D",
#             "mean_temp": 42.0,
#             "record_hi": 75.0,
#             "record_hi_yr": 1953,
#             "record_lo": 11.0,
#             "record_lo_yr": 1964,
#             "record_period": 30,
#             "station_id": "095988",
#             "station_name": "MONTICELLO"
#         }
#     ],
#     "metadata": {
#         "expire_time_gmt": 1489050502,
#         "language": "en-US",
#         "latitude": 33.4,
#         "longitude": -83.42,
#         "status_code": 200,
#         "transaction_id": "1488969584657:2078268009",
#         "units": "e",
#         "version": "1"
#     }
# }

# %% [markdown]
# ## Using location services
#
# ### Request by city name
# To request location information for a city, you must supply at least one query parameter, such as a city name, and a locationType of city. You can also supply the countryCode and adminDistrictCode to reduce the number of unique locations that can be retrieved.
#
# For example, the following request retrieves the location information for Atlanta, Georgia, US.

# %%
print_api_resp("api/weather/v3/location/search?query=Atlanta&locationType=city&countryCode=US&adminDistrictCode=GA&language=en-US",credentials_1)
# Out:
# {
#     "location": {
#         "address": [
#             "Atlanta, Georgia, United States"
#         ],
#         "adminDistrict": [
#             "Georgia"
#         ],
#         "adminDistrictCode": [
#             "GA"
#         ],
#         "city": [
#             "Atlanta"
#         ],
#         "country": [
#             "United States"
#         ],
#         "countryCode": [
#             "US"
#         ],
#         "displayName": [
#             "Atlanta"
#         ],
#         "ianaTimeZone": [
#             null
#         ],
#         "latitude": [
#             33.749
#         ],
#         "locale": [
#             {
#                 "locale1": "Atlanta",
#                 "locale2": null,
#                 "locale3": null,
#                 "locale4": null
#             }
#         ],
#         "longitude": [
#             -84.39
#         ],
#         "neighborhood": [
#             null
#         ],
#         "placeId": [
#             "8f5c8f0c5dd7699966caf7dcb4880c3860e15573a2d9ca8ea2f67f8dc10c4b52"
#         ],
#         "postalCode": [
#             "30303"
#         ],
#         "postalKey": [
#             null
#         ]
#     }
# }

# %% [markdown]
# ### Request by geocode
# To request a set of locations for a geocode, you must supply a valid latitude and longitude pair.
#
# For example, the following request retrieves the location information for the geo-coordinates of Atlanta, Georgia, US

# %%
print_api_resp("api/weather/v3/location/point?geocode=34.53%2C-84.50&language=en-US",credentials_1)
# Out:
# {
#     "location": {
#         "adminDistrict": "Georgia",
#         "adminDistrictCode": "GA",
#         "city": "Talking Rock",
#         "country": "United States",
#         "countryCode": "US",
#         "displayName": "Talking Rock",
#         "dstEnd": "2017-11-05T01:00:00-0500",
#         "dstStart": "2017-03-12T03:00:00-0400",
#         "ianaTimeZone": "America/New_York",
#         "latitude": 34.509,
#         "locale": {
#             "locale1": "Talking Rock",
#             "locale2": null,
#             "locale3": null,
#             "locale4": null
#         },
#         "longitude": -84.505,
#         "neighborhood": null,
#         "placeId": "8e6d6ef4c4402fa0c9e7a64b85b4f2cec075dd5e37ad672113bc581ba112e446",
#         "postalCode": "30175",
#         "postalKey": "30175:US"
#     }
# }

# %% [markdown]
# ### Request by postal code
# To request a set of locations by postal code, you must supply a postal key, which is a composite of a <postal code>:<country code>.
#
# For example, the following request retrieves the location information for a postal code in Atlanta, Georgia, US.

# %%
print_api_resp("api/weather/v3/location/point?postalKey=30339%3AUS&language=en-US",credentials_1)
# Out:
# {
#     "location": {
#         "adminDistrict": "Georgia",
#         "adminDistrictCode": "GA",
#         "city": "Atlanta",
#         "country": "United States",
#         "countryCode": "US",
#         "displayName": "Atlanta",
#         "dstEnd": "2017-11-05T01:00:00-0500",
#         "dstStart": "2017-03-12T03:00:00-0400",
#         "ianaTimeZone": "America/New_York",
#         "latitude": 33.749,
#         "locale": {
#             "locale1": "Atlanta",
#             "locale2": null,
#             "locale3": null,
#             "locale4": null
#         },
#         "longitude": -84.39,
#         "neighborhood": null,
#         "placeId": "8f5c8f0c5dd7699966caf7dcb4880c3860e15573a2d9ca8ea2f67f8dc10c4b52",
#         "postalCode": "30339",
#         "postalKey": "30339:US"
#     }
# }
