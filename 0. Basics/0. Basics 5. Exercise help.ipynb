# %% [markdown]
# # Moon phases

# %% [markdown]
# # This site contains the moon phases
# ### http://aa.usno.navy.mil/data/docs/MoonFraction.php
#
# # Download this data and convert in the appropraite format (think about what appropriate means)
# ### http://aa.usno.navy.mil/cgi-bin/aa_moonill2.pl?form=1&year=2017&task=00&tz=-05

# %%
import numpy as np
import pandas as pd
import requests
# %matplotlib inline

data=requests.get ("http://aa.usno.navy.mil/cgi-bin/aa_moonill2.pl?form=1&year=2017&task=00&tz=-05")
data=****.content[****:***].split("**")

header=data[*].split()

*=[]
for i in data[2:-1]:
    d.append(*.split("     "))
d=**.array(*)

df = **.DataFrame(d,columns=******).apply(**.to_numeric)

values =**.T.values[*:,:].reshape(*,*)
values=values[~np.isnan(******)]

result=**.DataFrame(**.date_range('2001','2002')[:**],*******=["date"])
result["****"]=values

result['moon'].plot()
